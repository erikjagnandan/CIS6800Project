# %% [markdown]
# _The following code requires having uploaded the dinov2 folder from our GitHub repository to your My Drive folder on Google Drive. There are further instructions below._

# %% [markdown]
# _Run the first 2 code blocks. After the second code block terminates, it will ask you to restart the session. Restart the session and then proceed to the next code block. You do not need to re-run the first two blocks after restarting the session._

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -U openmim
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.7)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.7)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (4.66.6)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.10/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.9 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.9 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 22.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 24.1 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.0 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 12.8 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 23.4 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.4 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 9.9 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 47.3 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 32.5 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 7.2 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=9500f24e2b40d6d6934fedda39b6f90c0c750d538aaf6516f8b0a401377632d7
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535316 sha256=7d6603dd64ae26d2bc57fa382515d1cf775b0775f9094c056cfb3618af8f1206
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31410 sha256=9973051cf264ab0e0eaa4b1f024a10fd863fd95ccbac71719cbf6d0236c993a1
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, pycryptodome, ordered-set, jmespath, filelock, colorama, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# pymc 5.18.2 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# pytensor 2.26.4 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# yfinance 0.2.50 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 colorama-0.4.6 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 pycryptodome-3.21.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20

# %% [markdown]
# _The next two blocks require some time to run (1-3 minutes total). Run them, and while they are running, do the following:_
#
# _Upload all images and ground truth depth maps to the /content directory. If you click on the Files tab to the left, you should be brought to the /content directory by default (you should see directories called .config and sample\_data). For example, your file system could look like /content/1.png, /content/1.jpg, /content/2.png, etc._
#
# _This code is designed to work for one scene at a time, so only upload the data for one scene. Performance metrics for multiple scenes can be easily obtained by running this code separately for each scene, and then taking the average of the performance on each scene, weighted by the number of samples in each scene._
#
# _The outputs in this notebook were computed specifically on the scene basement\_0001a\_out, whereas the performance reported in the paper is averaged across all scenes, so the performance metrics here will not perfectly match those in the paper._

# %%
# !mim install mmcv==1.5.0
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.5.0/index.html
# Collecting mmcv==1.5.0
#   Downloading mmcv-1.5.0.tar.gz (530 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting addict (from mmcv==1.5.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv==1.5.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv==1.5.0) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv==1.5.0) (11.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv==1.5.0) (6.0.2)
# Collecting yapf (from mmcv==1.5.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv==1.5.0) (4.3.6)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv==1.5.0) (2.2.1)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 15.0 MB/s eta 0:00:00
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-1.5.0-py2.py3-none-any.whl size=807180 sha256=b3375edf0c3722d978e88f63278697216fa96bec937de16b224a9a30417cf490
#   Stored in directory: /root/.cache/pip/wheels/86/b4/5d/1250f6319cd64acea208a8cd5a3e600506381c05bd65343d22
# Successfully built mmcv
# Installing collected packages: addict, yapf, mmcv
# Successfully installed addict-2.4.0 mmcv-1.5.0 yapf-0.43.0

# %%
import shutil

# Define the source and destination path
source_folder_path = '/content/gdrive/My Drive/dinov2'
destination_folder_path = '/content/dinov2'

# Copy the folder
shutil.copytree(source_folder_path, destination_folder_path)
# Out:
# '/content/dinov2'

# %% [markdown]
# _Run the next 5 blocks_

# %%
import os
from PIL import Image
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path
import sys
import math
import itertools
from functools import partial
import mmcv
from collections import defaultdict
import cv2
from google.colab.patches import cv2_imshow

from torchvision import transforms

from dinov2.eval.depth.models import build_depther

# %%
class CenterPadding(torch.nn.Module):
    def __init__(self, multiple):
        super().__init__()
        self.multiple = multiple

    def _get_pad(self, size):
        new_size = math.ceil(size / self.multiple) * self.multiple
        pad_size = new_size - size
        pad_size_left = pad_size // 2
        pad_size_right = pad_size - pad_size_left
        return pad_size_left, pad_size_right

    @torch.inference_mode()
    def forward(self, x):
        pads = list(itertools.chain.from_iterable(self._get_pad(m) for m in x.shape[:1:-1]))
        output = F.pad(x, pads)
        return output


def create_depther(cfg, backbone_model, backbone_size, head_type):
    train_cfg = cfg.get("train_cfg")
    test_cfg = cfg.get("test_cfg")
    depther = build_depther(cfg.model, train_cfg=train_cfg, test_cfg=test_cfg)

    depther.backbone.forward = partial(
        backbone_model.get_intermediate_layers,
        n=cfg.model.backbone.out_indices,
        reshape=True,
        return_class_token=cfg.model.backbone.output_cls_token,
        norm=cfg.model.backbone.final_norm,
    )

    if hasattr(backbone_model, "patch_size"):
        depther.backbone.register_forward_pre_hook(lambda _, x: CenterPadding(backbone_model.patch_size)(x[0]))

    return depther

# %%
def make_depth_transform() -> transforms.Compose:
    return transforms.Compose([
        transforms.ToTensor(),
        lambda x: 255.0 * x[:3], # Discard alpha component and scale by 255
        transforms.Normalize(
            mean=(123.675, 116.28, 103.53),
            std=(58.395, 57.12, 57.375),
        ),
    ])


def render_depth(values, colormap_name="magma_r") -> Image:
    min_value, max_value = values.min(), values.max()
    normalized_values = (values - min_value) / (max_value - min_value)

    colormap = matplotlib.colormaps[colormap_name]
    colors = colormap(normalized_values, bytes=True) # ((1)xhxwx4)
    colors = colors[:, :, :3] # Discard alpha component
    return Image.fromarray(colors)

# %% [markdown]
# _If you wish to change the size of the DINOv2 encoder, set BACKBONE\_SIZE accordingly._

# %%
BACKBONE_SIZE = "small" # in ("small", "base", "large" or "giant")


backbone_archs = {
    "small": "vits14",
    "base": "vitb14",
    "large": "vitl14",
    "giant": "vitg14",
}
backbone_arch = backbone_archs[BACKBONE_SIZE]
backbone_name = f"dinov2_{backbone_arch}"

backbone_model = torch.hub.load(repo_or_dir="facebookresearch/dinov2", model=backbone_name)
backbone_model.eval()
backbone_model.cuda()
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /content/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /content/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /content/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 170MB/s]
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
import urllib

import mmcv
from mmcv.runner import load_checkpoint


def load_config_from_url(url: str) -> str:
    with urllib.request.urlopen(url) as f:
        return f.read().decode()


HEAD_DATASET = "nyu" # in ("nyu", "kitti")
HEAD_TYPE = "dpt" # in ("linear", "linear4", "dpt")


DINOV2_BASE_URL = "https://dl.fbaipublicfiles.com/dinov2"
head_config_url = f"{DINOV2_BASE_URL}/{backbone_name}/{backbone_name}_{HEAD_DATASET}_{HEAD_TYPE}_config.py"
head_checkpoint_url = f"{DINOV2_BASE_URL}/{backbone_name}/{backbone_name}_{HEAD_DATASET}_{HEAD_TYPE}_head.pth"

cfg_str = load_config_from_url(head_config_url)
cfg = mmcv.Config.fromstring(cfg_str, file_format=".py")

model = create_depther(
    cfg,
    backbone_model=backbone_model,
    backbone_size=BACKBONE_SIZE,
    head_type=HEAD_TYPE,
)

load_checkpoint(model, head_checkpoint_url, map_location="cpu")
model.eval()
model.cuda()
# Out:
# load checkpoint from http path: https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_nyu_dpt_head.pth
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_nyu_dpt_head.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_nyu_dpt_head.pth
# 100%|██████████| 160M/160M [00:04<00:00, 40.6MB/s]
# DepthEncoderDecoder(
#   (backbone): DinoVisionTransformer()
#   (decode_head): DPTHead(
#     align_corners=False
#     (loss_decode): ModuleList(
#       (0): SigLoss()
#       (1): GradientLoss()
#     )
#     (conv_depth): HeadDepth(
#       (head): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Interpolate()
#         (2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU()
#         (4): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#     (reassemble_blocks): ReassembleBlocks(
#       (projects): ModuleList(
#         (0): ConvModule(
#           (conv): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ConvModule(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ConvModule(
#           (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): ConvModule(
#           (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (resize_layers): ModuleList(
#         (0): ConvTranspose2d(48, 48, kernel_size=(4, 4), stride=(4, 4))
#         (1): ConvTranspose2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#         (2): Identity()
#         (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (readout_projects): ModuleList(
#         (0-3): 4 x Sequential(
#           (0): Linear(in_features=768, out_features=384, bias=True)
#           (1): GELU(approximate='none')
#         )
#       )
#     )
#     (convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(48, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (1): ConvModule(
#         (conv): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): ConvModule(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): ConvModule(
#         (conv): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (fusion_blocks): ModuleList(
#       (0): FeatureFusionBlock(
#         (project): ConvModule(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (res_conv_unit1): None
#         (res_conv_unit2): PreActResidualConvUnit(
#           (conv1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (activate): ReLU(inplace=True)
#           )
#           (conv2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (activate): ReLU(inplace=True)
#           )
#         )
#       )
#       (1-3): 3 x FeatureFusionBlock(
#         (project): ConvModule(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (res_conv_unit1): PreActResidualConvUnit(
#           (conv1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (activate): ReLU(inplace=True)
#           )
#           (conv2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (res_conv_unit2): PreActResidualConvUnit(
#           (conv1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (activate): ReLU(inplace=True)
#           )
#           (conv2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (activate): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (project): ConvModule(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (activate): ReLU(inplace=True)
#     )
#   )
# )

# %% [markdown]
# _Set num\_images to the number of images for the scene you uploaded_

# %%
num_images = 281

# %% [markdown]
# _Run this block to set up the speed tests._

# %%
# Speed Test Setup

import cv2
import matplotlib.pyplot as plt
import numpy as np
import time

# %cd '/content/'

spatial_offset_pixels = 150
distance_threshold = 100
feature_algorithm = cv2.ORB_create(nfeatures=500)

image_height = 480
image_width = 640
original_dino_depth_map = torch.zeros((num_images, image_height, image_width))
updated_dino_depth_map = torch.zeros((num_images, image_height, image_width))
images = []
grayscale_images = []

for i in range(num_images):
    images.append(cv2.imread(str(i+1) + '.jpg'))
    grayscale_images.append(cv2.imread(str(i+1) + '.jpg', 0))

transform = make_depth_transform()
# Out:
# /content

# %% [markdown]
# _Run this block to test the speed of the Vanilla DINOv2 model._

# %%
# Speed Test - Vanilla Model

start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)

start.record()
for i in range(num_images):
    transformed_image = transform(images[i])
    batch = transformed_image.unsqueeze(0).cuda()

    with torch.no_grad():
        original_dino_depth_map[i] = model.whole_inference(batch, img_meta=None, rescale=True).squeeze()

end.record()
torch.cuda.synchronize()

avg_milliseconds_original = start.elapsed_time(end)/num_images
print("Vanilla DINOv2 Time for " + str(num_images) + " Forward Props = " + str(avg_milliseconds_original) + " milliseconds (" + str(1000/avg_milliseconds_original) + " Hz)")
# Out:
# Vanilla DINOv2 Time for 281 Forward Props = 141.99924933274022 milliseconds (7.0422907494161935 Hz)

# %% [markdown]
# _Run this block to test the speed of the Iteration 0 Pipeline. Set speed\_optimized=True for ORB Correspondence Speed and speed\_optimized=False for ORB Correspondence Accuracy._

# %%
# Speed Test - Iteration 0

speed_optimized = False

rho = 0.70

start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)

start.record()
for i in range(num_images):
    transformed_image = transform(images[i])
    batch = transformed_image.unsqueeze(0).cuda()

    with torch.no_grad():
        original_dino_depth_map[i] = model.whole_inference(batch, img_meta=None, rescale=True).squeeze()

    if i > 0:
        keypoints1, descriptors1 = feature_algorithm.detectAndCompute(images[i], None)
        keypoints2, descriptors2 = feature_algorithm.detectAndCompute(images[i-1], None)

        bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
        matches = bf.match(descriptors1, descriptors2)

        if speed_optimized:
            matches = [m for m in matches if m.distance < distance_threshold]

        sum_tensor = torch.zeros_like(original_dino_depth_map[0])
        count_tensor = torch.zeros_like(original_dino_depth_map[0])

        for index in range(len(matches)):
            match = matches[index]
            img1_idx = match.queryIdx
            img2_idx = match.trainIdx

            (x1, y1) = keypoints1[img1_idx].pt
            (x2, y2) = keypoints2[img2_idx].pt

            x1 = int(x1)
            y1 = int(y1)
            x2 = int(x2)
            y2 = int(y2)

            y1_start = max(y1 - spatial_offset_pixels, 0)
            y1_end = min(y1 + spatial_offset_pixels, image_height - 1)
            x1_start = max(x1 - spatial_offset_pixels, 0)
            x1_end = min(x1 + spatial_offset_pixels, image_width - 1)

            y2_start = max(y2 - spatial_offset_pixels, 0)
            y2_end = min(y2 + spatial_offset_pixels, image_height - 1)
            x2_start = max(x2 - spatial_offset_pixels, 0)
            x2_end = min(x2 + spatial_offset_pixels, image_width - 1)

            if y1_start == 0:
                y2_end = min(y2_end, y2_start + y1_end - y1_start)
            if y2_start == 0:
                y1_end = min(y1_end, y1_start + y2_end - y2_start)
            if y1_end == image_height - 1:
                y2_start = max(y2_start, y2_end - y1_end + y1_start)
            if y2_end == image_height - 1:
                y1_start = max(y1_start, y1_end - y2_end + y2_start)
            if x1_start == 0:
                x2_end = min(x2_end, x2_start + x1_end - x1_start)
            if x2_start == 0:
                x1_end = min(x1_end, x1_start + x2_end - x2_start)
            if x1_end == image_width - 1:
                x2_start = max(x2_start, x2_end - x1_end + x1_start)
            if x2_end == image_width - 1:
                x1_start = max(x1_start, x1_end - x2_end + x2_start)

            # Extract valid subregion from original_dino_depth_map
            subregion1 = original_dino_depth_map[i, y1_start:y1_end+1, x1_start:x1_end+1]
            subregion2 = original_dino_depth_map[i-1, y2_start:y2_end+1, x2_start:x2_end+1]

            sum_tensor[y1_start:y1_end+1, x1_start:x1_end+1] += rho * subregion1 + (1 - rho) * subregion2
            count_tensor[y1_start:y1_end+1, x1_start:x1_end+1] += 1

        updated_dino_depth_map[i] = original_dino_depth_map[i].clone()
        updated_dino_depth_map[i][count_tensor != 0] = sum_tensor[count_tensor != 0] / count_tensor[count_tensor != 0]

end.record()
torch.cuda.synchronize()

avg_milliseconds_iteration_0 = start.elapsed_time(end)/num_images
print("Iteration 0 Time for " + str(num_images) + " Forward Props = " + str(avg_milliseconds_iteration_0) + " milliseconds (" + str(1000/avg_milliseconds_iteration_0) + " Hz, " + str(100*(avg_milliseconds_iteration_0-avg_milliseconds_original)/avg_milliseconds_original) + " percent change relative to Vanilla DINOv2)")
# Out:
# Iteration 0 Time for 281 Forward Props = 283.9788701067616 milliseconds (3.5213887555227297 Hz, 99.98617699825097 percent change relative to Vanilla DINOv2)

# %% [markdown]
# _Run this block to test the speed of the Iteration 1 Pipeline._

# %%
# Speed Test - Iteration 1

rho = 0.83

start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)

start.record()
for i in range(num_images):
    transformed_image = transform(images[i])
    batch = transformed_image.unsqueeze(0).cuda()

    with torch.inference_mode():
        original_dino_depth_map[i] = model.whole_inference(batch, img_meta=None, rescale=True).squeeze()

    if i > 0:
        shift_x, shift_y = cv2.phaseCorrelate(np.float32(grayscale_images[i-1]), np.float32(grayscale_images[i]))[0]

        shift_x = round(shift_x)
        shift_y = round(shift_y)

        updated_dino_depth_map[i] = original_dino_depth_map[i].clone()

        if shift_x >= 0 and shift_y >= 0:
            updated_dino_depth_map[i, shift_y:, shift_x:] = rho * original_dino_depth_map[i, shift_y:, shift_x:] + (1 - rho) * original_dino_depth_map[i-1, :image_height-shift_y, :image_width-shift_x]
        elif shift_x >= 0 and shift_y < 0:
            updated_dino_depth_map[i, :image_height+shift_y, shift_x:] = rho * original_dino_depth_map[i, :image_height+shift_y, shift_x:] + (1 - rho) * original_dino_depth_map[i-1, -shift_y:, :image_width-shift_x]
        elif shift_x < 0 and shift_y >= 0:
            updated_dino_depth_map[i, shift_y:, :image_width+shift_x] = rho * original_dino_depth_map[i, shift_y:, :image_width+shift_x] + (1 - rho) * original_dino_depth_map[i-1, :image_height-shift_y, -shift_x:]
        else:
            updated_dino_depth_map[i, :image_height+shift_y, :image_width+shift_x] = rho * original_dino_depth_map[i, :image_height+shift_y, :image_width+shift_x] + (1 - rho) * original_dino_depth_map[i-1, -shift_y:, -shift_x:]

end.record()
torch.cuda.synchronize()

avg_milliseconds_iteration_1 = start.elapsed_time(end)/num_images
print("Iteration 1 Time for " + str(num_images) + " Forward Props = " + str(avg_milliseconds_iteration_1) + " milliseconds (" + str(1000/avg_milliseconds_iteration_1) + " Hz, " + str(100*(avg_milliseconds_iteration_1-avg_milliseconds_original)/avg_milliseconds_original) + " percent change relative to Vanilla DINOv2)")
# Out:
# Iteration 1 Time for 281 Forward Props = 145.62527802491104 milliseconds (6.866939679448628 Hz, 2.5535548315992265 percent change relative to Vanilla DINOv2)

# %% [markdown]
# _Run this block to test the accuracy of the Iteration 0 Pipeline, as compared to the Vanilla DINOv2 model. Set speed\_optimized=True for ORB Correspondence Speed and speed\_optimized=False for ORB Correspondence Accuracy._

# %%
# Accuracy Test - Iteration 0

import cv2
import matplotlib.pyplot as plt
import numpy as np

# %cd '/content/'

speed_optimized = False

spatial_offset_pixels = 150

rho = 0.70

image_height = 480
image_width = 640
ground_truth_depth = np.zeros((num_images, image_height, image_width))
original_dino_depth_map = torch.zeros((num_images, image_height, image_width))
updated_dino_depth_map = torch.zeros((num_images, image_height, image_width))
original_dino_mse = torch.zeros(num_images)
updated_dino_mse = torch.zeros(num_images)
difference = torch.zeros(num_images)
images = []

distance_threshold = 100

for i in range(num_images):
    images.append(cv2.imread(str(i+1) + '.jpg'))
    ground_truth_depth[i] = 10.0 * np.array(Image.open(str(i+1) + '.png')).astype(float)/255.0

feature_algorithm = cv2.ORB_create(nfeatures=500)
transform = make_depth_transform()

for i in range(num_images):
    transformed_image = transform(images[i])
    batch = transformed_image.unsqueeze(0).cuda()

    with torch.inference_mode():
        original_dino_depth_map[i] = model.whole_inference(batch, img_meta=None, rescale=True).squeeze()

    masked_true_depths = torch.tensor(ground_truth_depth[i][ground_truth_depth[i] > 0.0])
    original_masked_dino_depths = torch.tensor(original_dino_depth_map[i][ground_truth_depth[i] > 0.0])

    original_dino_mse[i] = F.mse_loss(original_masked_dino_depths, masked_true_depths)

    print("\nIteration 0 - Original Dino MSE for Image " + str(i) + " = " + str(original_dino_mse[i].item()))

    if i == 0:
        updated_dino_mse[i] = original_dino_mse[i]
        difference[i] = updated_dino_mse[i].item() - original_dino_mse[i].item()
    else:
        keypoints1, descriptors1 = feature_algorithm.detectAndCompute(images[i], None)
        keypoints2, descriptors2 = feature_algorithm.detectAndCompute(images[i-1], None)

        bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
        matches = bf.match(descriptors1, descriptors2)

        if speed_optimized:
            matches = [m for m in matches if m.distance < distance_threshold]

        sum_tensor = torch.zeros_like(original_dino_depth_map[0])
        count_tensor = torch.zeros_like(original_dino_depth_map[0])

        for index in range(len(matches)):
            match = matches[index]
            img1_idx = match.queryIdx
            img2_idx = match.trainIdx

            (x1, y1) = keypoints1[img1_idx].pt
            (x2, y2) = keypoints2[img2_idx].pt

            x1 = int(x1)
            y1 = int(y1)
            x2 = int(x2)
            y2 = int(y2)

            y1_start = max(y1 - spatial_offset_pixels, 0)
            y1_end = min(y1 + spatial_offset_pixels, image_height - 1)
            x1_start = max(x1 - spatial_offset_pixels, 0)
            x1_end = min(x1 + spatial_offset_pixels, image_width - 1)

            y2_start = max(y2 - spatial_offset_pixels, 0)
            y2_end = min(y2 + spatial_offset_pixels, image_height - 1)
            x2_start = max(x2 - spatial_offset_pixels, 0)
            x2_end = min(x2 + spatial_offset_pixels, image_width - 1)

            if y1_start == 0:
                y2_end = min(y2_end, y2_start + y1_end - y1_start)
            if y2_start == 0:
                y1_end = min(y1_end, y1_start + y2_end - y2_start)
            if y1_end == image_height - 1:
                y2_start = max(y2_start, y2_end - y1_end + y1_start)
            if y2_end == image_height - 1:
                y1_start = max(y1_start, y1_end - y2_end + y2_start)
            if x1_start == 0:
                x2_end = min(x2_end, x2_start + x1_end - x1_start)
            if x2_start == 0:
                x1_end = min(x1_end, x1_start + x2_end - x2_start)
            if x1_end == image_width - 1:
                x2_start = max(x2_start, x2_end - x1_end + x1_start)
            if x2_end == image_width - 1:
                x1_start = max(x1_start, x1_end - x2_end + x2_start)

            # Extract valid subregion from original_dino_depth_map
            subregion1 = original_dino_depth_map[i, y1_start:y1_end+1, x1_start:x1_end+1]
            subregion2 = original_dino_depth_map[i-1, y2_start:y2_end+1, x2_start:x2_end+1]

            sum_tensor[y1_start:y1_end+1, x1_start:x1_end+1] += rho * subregion1 + (1 - rho) * subregion2
            count_tensor[y1_start:y1_end+1, x1_start:x1_end+1] += 1

        average = original_dino_depth_map[i].clone()
        average[count_tensor != 0] = sum_tensor[count_tensor != 0] / count_tensor[count_tensor != 0]

        updated_dino_depth_map[i] = average.clone()

        updated_masked_dino_depths = torch.tensor(updated_dino_depth_map[i][ground_truth_depth[i] > 0.0])

        updated_dino_mse[i] = F.mse_loss(updated_masked_dino_depths, masked_true_depths)

        print("Iteration 0 - Updated Dino MSE for Image " + str(i) + " = " + str(updated_dino_mse[i].item()))

        difference[i] = updated_dino_mse[i].item() - original_dino_mse[i].item()

        print("Iteration 0 - Difference = " + str(difference[i].item()))

print("\nIteration 0 - Mean Original DINO MSE Across " + str(num_images) + " Images = " + str(torch.mean(original_dino_mse).item()))
print("Iteration 0 - Mean Updated DINO MSE Across " + str(num_images) + " Images = " + str(torch.mean(updated_dino_mse).item()))
print("Iteration 0 - Mean Difference Across " + str(num_images) + " Images = " + str(torch.mean(difference).item()) + ", (" + str(torch.mean(difference).item()/torch.mean(original_dino_mse).item()*100) + " percent change relative to Vanilla DINOv2)")
# Out:
# /content
# <ipython-input-55-0045978bba3f>:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   original_masked_dino_depths = torch.tensor(original_dino_depth_map[i][ground_truth_depth[i] > 0.0])
# Iteration 0 - Original Dino MSE for Image 0 = 0.4600278437137604
#
# Iteration 0 - Original Dino MSE for Image 1 = 0.33338451385498047
# <ipython-input-55-0045978bba3f>:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   updated_masked_dino_depths = torch.tensor(updated_dino_depth_map[i][ground_truth_depth[i] > 0.0])
# Iteration 0 - Updated Dino MSE for Image 1 = 0.33806440234184265
# Iteration 0 - Difference = 0.004679888486862183
#
# Iteration 0 - Original Dino MSE for Image 2 = 0.3002174198627472
# Iteration 0 - Updated Dino MSE for Image 2 = 0.25804051756858826
# Iteration 0 - Difference = -0.042176902294158936
#
# Iteration 0 - Original Dino MSE for Image 3 = 0.23217007517814636
# Iteration 0 - Updated Dino MSE for Image 3 = 0.20629426836967468
# Iteration 0 - Difference = -0.02587580680847168
#
# Iteration 0 - Original Dino MSE for Image 4 = 0.16918054223060608
# Iteration 0 - Updated Dino MSE for Image 4 = 0.1607423573732376
# Iteration 0 - Difference = -0.00843818485736847
#
# Iteration 0 - Original Dino MSE for Image 5 = 0.1919342428445816
# Iteration 0 - Updated Dino MSE for Image 5 = 0.1652613878250122
# Iteration 0 - Difference = -0.026672855019569397
#
# Iteration 0 - Original Dino MSE for Image 6 = 0.12380967289209366
# Iteration 0 - Updated Dino MSE for Image 6 = 0.1227167546749115
# Iteration 0 - Difference = -0.0010929182171821594
#
# Iteration 0 - Original Dino MSE for Image 7 = 0.15247498452663422
# Iteration 0 - Updated Dino MSE for Image 7 = 0.13241112232208252
# Iteration 0 - Difference = -0.020063862204551697
#
# Iteration 0 - Original Dino MSE for Image 8 = 0.19276215136051178
# Iteration 0 - Updated Dino MSE for Image 8 = 0.1710081696510315
# Iteration 0 - Difference = -0.021753981709480286
#
# Iteration 0 - Original Dino MSE for Image 9 = 0.2151387631893158
# Iteration 0 - Updated Dino MSE for Image 9 = 0.19848065078258514
# Iteration 0 - Difference = -0.016658112406730652
#
# Iteration 0 - Original Dino MSE for Image 10 = 0.1524471640586853
# Iteration 0 - Updated Dino MSE for Image 10 = 0.15943364799022675
# Iteration 0 - Difference = 0.006986483931541443
#
# Iteration 0 - Original Dino MSE for Image 11 = 0.2388329654932022
# Iteration 0 - Updated Dino MSE for Image 11 = 0.2028573602437973
# Iteration 0 - Difference = -0.03597560524940491
#
# Iteration 0 - Original Dino MSE for Image 12 = 0.19232597947120667
# Iteration 0 - Updated Dino MSE for Image 12 = 0.17515267431735992
# Iteration 0 - Difference = -0.01717330515384674
#
# Iteration 0 - Original Dino MSE for Image 13 = 0.23566646873950958
# Iteration 0 - Updated Dino MSE for Image 13 = 0.18360953032970428
# Iteration 0 - Difference = -0.0520569384098053
#
# Iteration 0 - Original Dino MSE for Image 14 = 0.21828904747962952
# Iteration 0 - Updated Dino MSE for Image 14 = 0.2020656168460846
# Iteration 0 - Difference = -0.016223430633544922
#
# Iteration 0 - Original Dino MSE for Image 15 = 0.21649333834648132
# Iteration 0 - Updated Dino MSE for Image 15 = 0.21175426244735718
# Iteration 0 - Difference = -0.0047390758991241455
#
# Iteration 0 - Original Dino MSE for Image 16 = 0.2788110673427582
# Iteration 0 - Updated Dino MSE for Image 16 = 0.25063496828079224
# Iteration 0 - Difference = -0.028176099061965942
#
# Iteration 0 - Original Dino MSE for Image 17 = 0.2991960048675537
# Iteration 0 - Updated Dino MSE for Image 17 = 0.2724165618419647
# Iteration 0 - Difference = -0.02677944302558899
#
# Iteration 0 - Original Dino MSE for Image 18 = 0.2939864695072174
# Iteration 0 - Updated Dino MSE for Image 18 = 0.2664935290813446
# Iteration 0 - Difference = -0.027492940425872803
#
# Iteration 0 - Original Dino MSE for Image 19 = 0.2822563052177429
# Iteration 0 - Updated Dino MSE for Image 19 = 0.27065208554267883
# Iteration 0 - Difference = -0.011604219675064087
#
# Iteration 0 - Original Dino MSE for Image 20 = 0.20997768640518188
# Iteration 0 - Updated Dino MSE for Image 20 = 0.20826077461242676
# Iteration 0 - Difference = -0.001716911792755127
#
# Iteration 0 - Original Dino MSE for Image 21 = 0.1793728619813919
# Iteration 0 - Updated Dino MSE for Image 21 = 0.174981489777565
# Iteration 0 - Difference = -0.004391372203826904
#
# Iteration 0 - Original Dino MSE for Image 22 = 0.21577952802181244
# Iteration 0 - Updated Dino MSE for Image 22 = 0.1781555414199829
# Iteration 0 - Difference = -0.03762398660182953
#
# Iteration 0 - Original Dino MSE for Image 23 = 0.1802201122045517
# Iteration 0 - Updated Dino MSE for Image 23 = 0.1780017614364624
# Iteration 0 - Difference = -0.0022183507680892944
#
# Iteration 0 - Original Dino MSE for Image 24 = 0.16809576749801636
# Iteration 0 - Updated Dino MSE for Image 24 = 0.15446120500564575
# Iteration 0 - Difference = -0.013634562492370605
#
# Iteration 0 - Original Dino MSE for Image 25 = 0.1732526421546936
# Iteration 0 - Updated Dino MSE for Image 25 = 0.15957920253276825
# Iteration 0 - Difference = -0.013673439621925354
#
# Iteration 0 - Original Dino MSE for Image 26 = 0.2554466724395752
# Iteration 0 - Updated Dino MSE for Image 26 = 0.21371221542358398
# Iteration 0 - Difference = -0.04173445701599121
#
# Iteration 0 - Original Dino MSE for Image 27 = 0.23703376948833466
# Iteration 0 - Updated Dino MSE for Image 27 = 0.231867253780365
# Iteration 0 - Difference = -0.0051665157079696655
#
# Iteration 0 - Original Dino MSE for Image 28 = 0.2237587571144104
# Iteration 0 - Updated Dino MSE for Image 28 = 0.21703088283538818
# Iteration 0 - Difference = -0.006727874279022217
#
# Iteration 0 - Original Dino MSE for Image 29 = 0.18382135033607483
# Iteration 0 - Updated Dino MSE for Image 29 = 0.18455354869365692
# Iteration 0 - Difference = 0.0007321983575820923
#
# Iteration 0 - Original Dino MSE for Image 30 = 0.2309509515762329
# Iteration 0 - Updated Dino MSE for Image 30 = 0.2086489498615265
# Iteration 0 - Difference = -0.02230200171470642
#
# Iteration 0 - Original Dino MSE for Image 31 = 0.17370520532131195
# Iteration 0 - Updated Dino MSE for Image 31 = 0.1732751578092575
# Iteration 0 - Difference = -0.00043004751205444336
#
# Iteration 0 - Original Dino MSE for Image 32 = 0.21889425814151764
# Iteration 0 - Updated Dino MSE for Image 32 = 0.1818026453256607
# Iteration 0 - Difference = -0.037091612815856934
#
# Iteration 0 - Original Dino MSE for Image 33 = 0.46187323331832886
# Iteration 0 - Updated Dino MSE for Image 33 = 0.3586401045322418
# Iteration 0 - Difference = -0.10323312878608704
#
# Iteration 0 - Original Dino MSE for Image 34 = 0.38091546297073364
# Iteration 0 - Updated Dino MSE for Image 34 = 0.31283190846443176
# Iteration 0 - Difference = -0.06808355450630188
#
# Iteration 0 - Original Dino MSE for Image 35 = 0.2250550091266632
# Iteration 0 - Updated Dino MSE for Image 35 = 0.22723208367824554
# Iteration 0 - Difference = 0.0021770745515823364
#
# Iteration 0 - Original Dino MSE for Image 36 = 0.21850505471229553
# Iteration 0 - Updated Dino MSE for Image 36 = 0.2082081437110901
# Iteration 0 - Difference = -0.010296911001205444
#
# Iteration 0 - Original Dino MSE for Image 37 = 0.23471471667289734
# Iteration 0 - Updated Dino MSE for Image 37 = 0.22762204706668854
# Iteration 0 - Difference = -0.007092669606208801
#
# Iteration 0 - Original Dino MSE for Image 38 = 0.2461712658405304
# Iteration 0 - Updated Dino MSE for Image 38 = 0.23891310393810272
# Iteration 0 - Difference = -0.007258161902427673
#
# Iteration 0 - Original Dino MSE for Image 39 = 0.25165921449661255
# Iteration 0 - Updated Dino MSE for Image 39 = 0.2333088517189026
# Iteration 0 - Difference = -0.01835036277770996
#
# Iteration 0 - Original Dino MSE for Image 40 = 0.23710371553897858
# Iteration 0 - Updated Dino MSE for Image 40 = 0.23179945349693298
# Iteration 0 - Difference = -0.005304262042045593
#
# Iteration 0 - Original Dino MSE for Image 41 = 0.20689231157302856
# Iteration 0 - Updated Dino MSE for Image 41 = 0.20779851078987122
# Iteration 0 - Difference = 0.0009061992168426514
#
# Iteration 0 - Original Dino MSE for Image 42 = 0.23623701930046082
# Iteration 0 - Updated Dino MSE for Image 42 = 0.2329113781452179
# Iteration 0 - Difference = -0.00332564115524292
#
# Iteration 0 - Original Dino MSE for Image 43 = 0.31441691517829895
# Iteration 0 - Updated Dino MSE for Image 43 = 0.28080111742019653
# Iteration 0 - Difference = -0.03361579775810242
#
# Iteration 0 - Original Dino MSE for Image 44 = 0.286571204662323
# Iteration 0 - Updated Dino MSE for Image 44 = 0.28146058320999146
# Iteration 0 - Difference = -0.005110621452331543
#
# Iteration 0 - Original Dino MSE for Image 45 = 0.44337138533592224
# Iteration 0 - Updated Dino MSE for Image 45 = 0.4064137935638428
# Iteration 0 - Difference = -0.03695759177207947
#
# Iteration 0 - Original Dino MSE for Image 46 = 0.2658337950706482
# Iteration 0 - Updated Dino MSE for Image 46 = 0.2720412313938141
# Iteration 0 - Difference = 0.0062074363231658936
#
# Iteration 0 - Original Dino MSE for Image 47 = 0.3117736279964447
# Iteration 0 - Updated Dino MSE for Image 47 = 0.28696733713150024
# Iteration 0 - Difference = -0.024806290864944458
#
# Iteration 0 - Original Dino MSE for Image 48 = 0.26211023330688477
# Iteration 0 - Updated Dino MSE for Image 48 = 0.23249241709709167
# Iteration 0 - Difference = -0.02961781620979309
#
# Iteration 0 - Original Dino MSE for Image 49 = 0.2000478208065033
# Iteration 0 - Updated Dino MSE for Image 49 = 0.20192697644233704
# Iteration 0 - Difference = 0.0018791556358337402
#
# Iteration 0 - Original Dino MSE for Image 50 = 0.23981180787086487
# Iteration 0 - Updated Dino MSE for Image 50 = 0.2208179235458374
# Iteration 0 - Difference = -0.018993884325027466
#
# Iteration 0 - Original Dino MSE for Image 51 = 0.2845131754875183
# Iteration 0 - Updated Dino MSE for Image 51 = 0.2566479742527008
# Iteration 0 - Difference = -0.027865201234817505
#
# Iteration 0 - Original Dino MSE for Image 52 = 0.222128763794899
# Iteration 0 - Updated Dino MSE for Image 52 = 0.24956829845905304
# Iteration 0 - Difference = 0.027439534664154053
#
# Iteration 0 - Original Dino MSE for Image 53 = 0.214969202876091
# Iteration 0 - Updated Dino MSE for Image 53 = 0.20628413558006287
# Iteration 0 - Difference = -0.008685067296028137
#
# Iteration 0 - Original Dino MSE for Image 54 = 0.17861036956310272
# Iteration 0 - Updated Dino MSE for Image 54 = 0.16094614565372467
# Iteration 0 - Difference = -0.017664223909378052
#
# Iteration 0 - Original Dino MSE for Image 55 = 0.1671760082244873
# Iteration 0 - Updated Dino MSE for Image 55 = 0.16121038794517517
# Iteration 0 - Difference = -0.005965620279312134
#
# Iteration 0 - Original Dino MSE for Image 56 = 0.2929726839065552
# Iteration 0 - Updated Dino MSE for Image 56 = 0.24873405694961548
# Iteration 0 - Difference = -0.0442386269569397
#
# Iteration 0 - Original Dino MSE for Image 57 = 0.24876074492931366
# Iteration 0 - Updated Dino MSE for Image 57 = 0.26593920588493347
# Iteration 0 - Difference = 0.017178460955619812
#
# Iteration 0 - Original Dino MSE for Image 58 = 0.29977306723594666
# Iteration 0 - Updated Dino MSE for Image 58 = 0.2751959264278412
# Iteration 0 - Difference = -0.02457714080810547
#
# Iteration 0 - Original Dino MSE for Image 59 = 0.21820387244224548
# Iteration 0 - Updated Dino MSE for Image 59 = 0.22271884977817535
# Iteration 0 - Difference = 0.004514977335929871
#
# Iteration 0 - Original Dino MSE for Image 60 = 0.29151013493537903
# Iteration 0 - Updated Dino MSE for Image 60 = 0.2833484709262848
# Iteration 0 - Difference = -0.008161664009094238
#
# Iteration 0 - Original Dino MSE for Image 61 = 0.27752965688705444
# Iteration 0 - Updated Dino MSE for Image 61 = 0.2715296447277069
# Iteration 0 - Difference = -0.006000012159347534
#
# Iteration 0 - Original Dino MSE for Image 62 = 0.2895907461643219
# Iteration 0 - Updated Dino MSE for Image 62 = 0.2785492539405823
# Iteration 0 - Difference = -0.011041492223739624
#
# Iteration 0 - Original Dino MSE for Image 63 = 0.2052570879459381
# Iteration 0 - Updated Dino MSE for Image 63 = 0.24139352142810822
# Iteration 0 - Difference = 0.036136433482170105
#
# Iteration 0 - Original Dino MSE for Image 64 = 0.15977320075035095
# Iteration 0 - Updated Dino MSE for Image 64 = 0.1655772179365158
# Iteration 0 - Difference = 0.005804017186164856
#
# Iteration 0 - Original Dino MSE for Image 65 = 0.2917775809764862
# Iteration 0 - Updated Dino MSE for Image 65 = 0.3208801746368408
# Iteration 0 - Difference = 0.029102593660354614
#
# Iteration 0 - Original Dino MSE for Image 66 = 0.16730399429798126
# Iteration 0 - Updated Dino MSE for Image 66 = 0.20371852815151215
# Iteration 0 - Difference = 0.036414533853530884
#
# Iteration 0 - Original Dino MSE for Image 67 = 0.11794400215148926
# Iteration 0 - Updated Dino MSE for Image 67 = 0.10598871856927872
# Iteration 0 - Difference = -0.01195528358221054
#
# Iteration 0 - Original Dino MSE for Image 68 = 0.1530061513185501
# Iteration 0 - Updated Dino MSE for Image 68 = 0.1367795467376709
# Iteration 0 - Difference = -0.01622660458087921
#
# Iteration 0 - Original Dino MSE for Image 69 = 0.2852895259857178
# Iteration 0 - Updated Dino MSE for Image 69 = 0.23442618548870087
# Iteration 0 - Difference = -0.05086334049701691
#
# Iteration 0 - Original Dino MSE for Image 70 = 0.08763149380683899
# Iteration 0 - Updated Dino MSE for Image 70 = 0.11414244025945663
# Iteration 0 - Difference = 0.026510946452617645
#
# Iteration 0 - Original Dino MSE for Image 71 = 0.16887402534484863
# Iteration 0 - Updated Dino MSE for Image 71 = 0.1374894380569458
# Iteration 0 - Difference = -0.03138458728790283
#
# Iteration 0 - Original Dino MSE for Image 72 = 0.11875037103891373
# Iteration 0 - Updated Dino MSE for Image 72 = 0.13231869041919708
# Iteration 0 - Difference = 0.013568319380283356
#
# Iteration 0 - Original Dino MSE for Image 73 = 0.18007215857505798
# Iteration 0 - Updated Dino MSE for Image 73 = 0.15288956463336945
# Iteration 0 - Difference = -0.027182593941688538
#
# Iteration 0 - Original Dino MSE for Image 74 = 0.11179962009191513
# Iteration 0 - Updated Dino MSE for Image 74 = 0.11790882796049118
# Iteration 0 - Difference = 0.00610920786857605
#
# Iteration 0 - Original Dino MSE for Image 75 = 0.20570288598537445
# Iteration 0 - Updated Dino MSE for Image 75 = 0.1644418090581894
# Iteration 0 - Difference = -0.04126107692718506
#
# Iteration 0 - Original Dino MSE for Image 76 = 0.19121937453746796
# Iteration 0 - Updated Dino MSE for Image 76 = 0.18798254430294037
# Iteration 0 - Difference = -0.003236830234527588
#
# Iteration 0 - Original Dino MSE for Image 77 = 0.1626543253660202
# Iteration 0 - Updated Dino MSE for Image 77 = 0.16831910610198975
# Iteration 0 - Difference = 0.0056647807359695435
#
# Iteration 0 - Original Dino MSE for Image 78 = 0.1116304099559784
# Iteration 0 - Updated Dino MSE for Image 78 = 0.11921051144599915
# Iteration 0 - Difference = 0.007580101490020752
#
# Iteration 0 - Original Dino MSE for Image 79 = 0.14166167378425598
# Iteration 0 - Updated Dino MSE for Image 79 = 0.12359403818845749
# Iteration 0 - Difference = -0.018067635595798492
#
# Iteration 0 - Original Dino MSE for Image 80 = 0.1318349987268448
# Iteration 0 - Updated Dino MSE for Image 80 = 0.12779054045677185
# Iteration 0 - Difference = -0.004044458270072937
#
# Iteration 0 - Original Dino MSE for Image 81 = 0.1495172381401062
# Iteration 0 - Updated Dino MSE for Image 81 = 0.13626669347286224
# Iteration 0 - Difference = -0.013250544667243958
#
# Iteration 0 - Original Dino MSE for Image 82 = 0.1372205913066864
# Iteration 0 - Updated Dino MSE for Image 82 = 0.12895476818084717
# Iteration 0 - Difference = -0.008265823125839233
#
# Iteration 0 - Original Dino MSE for Image 83 = 0.11035030335187912
# Iteration 0 - Updated Dino MSE for Image 83 = 0.10913953185081482
# Iteration 0 - Difference = -0.0012107715010643005
#
# Iteration 0 - Original Dino MSE for Image 84 = 0.12822633981704712
# Iteration 0 - Updated Dino MSE for Image 84 = 0.11341901868581772
# Iteration 0 - Difference = -0.0148073211312294
#
# Iteration 0 - Original Dino MSE for Image 85 = 0.1157885491847992
# Iteration 0 - Updated Dino MSE for Image 85 = 0.10662427544593811
# Iteration 0 - Difference = -0.009164273738861084
#
# Iteration 0 - Original Dino MSE for Image 86 = 0.1069382056593895
# Iteration 0 - Updated Dino MSE for Image 86 = 0.09695229679346085
# Iteration 0 - Difference = -0.00998590886592865
#
# Iteration 0 - Original Dino MSE for Image 87 = 0.11483161896467209
# Iteration 0 - Updated Dino MSE for Image 87 = 0.09625406563282013
# Iteration 0 - Difference = -0.01857755333185196
#
# Iteration 0 - Original Dino MSE for Image 88 = 0.09089407324790955
# Iteration 0 - Updated Dino MSE for Image 88 = 0.08709347993135452
# Iteration 0 - Difference = -0.003800593316555023
#
# Iteration 0 - Original Dino MSE for Image 89 = 0.11098245531320572
# Iteration 0 - Updated Dino MSE for Image 89 = 0.09420915693044662
# Iteration 0 - Difference = -0.016773298382759094
#
# Iteration 0 - Original Dino MSE for Image 90 = 0.2806840240955353
# Iteration 0 - Updated Dino MSE for Image 90 = 0.20905710756778717
# Iteration 0 - Difference = -0.07162691652774811
#
# Iteration 0 - Original Dino MSE for Image 91 = 0.2136581689119339
# Iteration 0 - Updated Dino MSE for Image 91 = 0.22562864422798157
# Iteration 0 - Difference = 0.011970475316047668
#
# Iteration 0 - Original Dino MSE for Image 92 = 0.1589306741952896
# Iteration 0 - Updated Dino MSE for Image 92 = 0.16635915637016296
# Iteration 0 - Difference = 0.007428482174873352
#
# Iteration 0 - Original Dino MSE for Image 93 = 0.1770540475845337
# Iteration 0 - Updated Dino MSE for Image 93 = 0.1669008582830429
# Iteration 0 - Difference = -0.010153189301490784
#
# Iteration 0 - Original Dino MSE for Image 94 = 0.1413079798221588
# Iteration 0 - Updated Dino MSE for Image 94 = 0.14186954498291016
# Iteration 0 - Difference = 0.0005615651607513428
#
# Iteration 0 - Original Dino MSE for Image 95 = 0.17052863538265228
# Iteration 0 - Updated Dino MSE for Image 95 = 0.15073314309120178
# Iteration 0 - Difference = -0.0197954922914505
#
# Iteration 0 - Original Dino MSE for Image 96 = 0.18533554673194885
# Iteration 0 - Updated Dino MSE for Image 96 = 0.1854325532913208
# Iteration 0 - Difference = 9.700655937194824e-05
#
# Iteration 0 - Original Dino MSE for Image 97 = 0.20922590792179108
# Iteration 0 - Updated Dino MSE for Image 97 = 0.1866273283958435
# Iteration 0 - Difference = -0.02259857952594757
#
# Iteration 0 - Original Dino MSE for Image 98 = 0.2591285705566406
# Iteration 0 - Updated Dino MSE for Image 98 = 0.21874409914016724
# Iteration 0 - Difference = -0.04038447141647339
#
# Iteration 0 - Original Dino MSE for Image 99 = 0.23973414301872253
# Iteration 0 - Updated Dino MSE for Image 99 = 0.19818708300590515
# Iteration 0 - Difference = -0.04154706001281738
#
# Iteration 0 - Original Dino MSE for Image 100 = 0.17926110327243805
# Iteration 0 - Updated Dino MSE for Image 100 = 0.14589598774909973
# Iteration 0 - Difference = -0.03336511552333832
#
# Iteration 0 - Original Dino MSE for Image 101 = 0.14621230959892273
# Iteration 0 - Updated Dino MSE for Image 101 = 0.1387096643447876
# Iteration 0 - Difference = -0.007502645254135132
#
# Iteration 0 - Original Dino MSE for Image 102 = 0.1065438985824585
# Iteration 0 - Updated Dino MSE for Image 102 = 0.11429541558027267
# Iteration 0 - Difference = 0.0077515169978141785
#
# Iteration 0 - Original Dino MSE for Image 103 = 0.10774075239896774
# Iteration 0 - Updated Dino MSE for Image 103 = 0.1025901511311531
# Iteration 0 - Difference = -0.005150601267814636
#
# Iteration 0 - Original Dino MSE for Image 104 = 0.09281272441148758
# Iteration 0 - Updated Dino MSE for Image 104 = 0.07985709607601166
# Iteration 0 - Difference = -0.012955628335475922
#
# Iteration 0 - Original Dino MSE for Image 105 = 0.06975442916154861
# Iteration 0 - Updated Dino MSE for Image 105 = 0.07914437353610992
# Iteration 0 - Difference = 0.00938994437456131
#
# Iteration 0 - Original Dino MSE for Image 106 = 0.06481579691171646
# Iteration 0 - Updated Dino MSE for Image 106 = 0.06673424690961838
# Iteration 0 - Difference = 0.0019184499979019165
#
# Iteration 0 - Original Dino MSE for Image 107 = 0.04986676573753357
# Iteration 0 - Updated Dino MSE for Image 107 = 0.04719427600502968
# Iteration 0 - Difference = -0.002672489732503891
#
# Iteration 0 - Original Dino MSE for Image 108 = 0.047929778695106506
# Iteration 0 - Updated Dino MSE for Image 108 = 0.048820193856954575
# Iteration 0 - Difference = 0.0008904151618480682
#
# Iteration 0 - Original Dino MSE for Image 109 = 0.05050256475806236
# Iteration 0 - Updated Dino MSE for Image 109 = 0.04994116351008415
# Iteration 0 - Difference = -0.0005614012479782104
#
# Iteration 0 - Original Dino MSE for Image 110 = 0.07430195808410645
# Iteration 0 - Updated Dino MSE for Image 110 = 0.07008352875709534
# Iteration 0 - Difference = -0.004218429327011108
#
# Iteration 0 - Original Dino MSE for Image 111 = 0.08451830595731735
# Iteration 0 - Updated Dino MSE for Image 111 = 0.08405985683202744
# Iteration 0 - Difference = -0.000458449125289917
#
# Iteration 0 - Original Dino MSE for Image 112 = 0.12199191749095917
# Iteration 0 - Updated Dino MSE for Image 112 = 0.12412213534116745
# Iteration 0 - Difference = 0.0021302178502082825
#
# Iteration 0 - Original Dino MSE for Image 113 = 0.11876928061246872
# Iteration 0 - Updated Dino MSE for Image 113 = 0.14185123145580292
# Iteration 0 - Difference = 0.023081950843334198
#
# Iteration 0 - Original Dino MSE for Image 114 = 0.20700399577617645
# Iteration 0 - Updated Dino MSE for Image 114 = 0.19412189722061157
# Iteration 0 - Difference = -0.01288209855556488
#
# Iteration 0 - Original Dino MSE for Image 115 = 0.15067467093467712
# Iteration 0 - Updated Dino MSE for Image 115 = 0.15034961700439453
# Iteration 0 - Difference = -0.0003250539302825928
#
# Iteration 0 - Original Dino MSE for Image 116 = 0.13522978127002716
# Iteration 0 - Updated Dino MSE for Image 116 = 0.1305868923664093
# Iteration 0 - Difference = -0.004642888903617859
#
# Iteration 0 - Original Dino MSE for Image 117 = 0.09423166513442993
# Iteration 0 - Updated Dino MSE for Image 117 = 0.08894886821508408
# Iteration 0 - Difference = -0.005282796919345856
#
# Iteration 0 - Original Dino MSE for Image 118 = 0.11143999546766281
# Iteration 0 - Updated Dino MSE for Image 118 = 0.09559285640716553
# Iteration 0 - Difference = -0.015847139060497284
#
# Iteration 0 - Original Dino MSE for Image 119 = 0.10771160572767258
# Iteration 0 - Updated Dino MSE for Image 119 = 0.10607689619064331
# Iteration 0 - Difference = -0.0016347095370292664
#
# Iteration 0 - Original Dino MSE for Image 120 = 0.08437409996986389
# Iteration 0 - Updated Dino MSE for Image 120 = 0.09817789494991302
# Iteration 0 - Difference = 0.013803794980049133
#
# Iteration 0 - Original Dino MSE for Image 121 = 0.2076818346977234
# Iteration 0 - Updated Dino MSE for Image 121 = 0.15012013912200928
# Iteration 0 - Difference = -0.05756169557571411
#
# Iteration 0 - Original Dino MSE for Image 122 = 0.12535500526428223
# Iteration 0 - Updated Dino MSE for Image 122 = 0.12742187082767487
# Iteration 0 - Difference = 0.002066865563392639
#
# Iteration 0 - Original Dino MSE for Image 123 = 0.13278841972351074
# Iteration 0 - Updated Dino MSE for Image 123 = 0.1277906894683838
# Iteration 0 - Difference = -0.004997730255126953
#
# Iteration 0 - Original Dino MSE for Image 124 = 0.12246620655059814
# Iteration 0 - Updated Dino MSE for Image 124 = 0.11289173364639282
# Iteration 0 - Difference = -0.009574472904205322
#
# Iteration 0 - Original Dino MSE for Image 125 = 0.1660168170928955
# Iteration 0 - Updated Dino MSE for Image 125 = 0.14426958560943604
# Iteration 0 - Difference = -0.021747231483459473
#
# Iteration 0 - Original Dino MSE for Image 126 = 0.14669793844223022
# Iteration 0 - Updated Dino MSE for Image 126 = 0.14561119675636292
# Iteration 0 - Difference = -0.0010867416858673096
#
# Iteration 0 - Original Dino MSE for Image 127 = 0.19247817993164062
# Iteration 0 - Updated Dino MSE for Image 127 = 0.17041797935962677
# Iteration 0 - Difference = -0.022060200572013855
#
# Iteration 0 - Original Dino MSE for Image 128 = 0.21111491322517395
# Iteration 0 - Updated Dino MSE for Image 128 = 0.20905503630638123
# Iteration 0 - Difference = -0.0020598769187927246
#
# Iteration 0 - Original Dino MSE for Image 129 = 0.15272866189479828
# Iteration 0 - Updated Dino MSE for Image 129 = 0.13351282477378845
# Iteration 0 - Difference = -0.019215837121009827
#
# Iteration 0 - Original Dino MSE for Image 130 = 0.19246485829353333
# Iteration 0 - Updated Dino MSE for Image 130 = 0.1864326149225235
# Iteration 0 - Difference = -0.006032243371009827
#
# Iteration 0 - Original Dino MSE for Image 131 = 0.11564312130212784
# Iteration 0 - Updated Dino MSE for Image 131 = 0.11561079323291779
# Iteration 0 - Difference = -3.232806921005249e-05
#
# Iteration 0 - Original Dino MSE for Image 132 = 0.117696613073349
# Iteration 0 - Updated Dino MSE for Image 132 = 0.1108756810426712
# Iteration 0 - Difference = -0.006820932030677795
#
# Iteration 0 - Original Dino MSE for Image 133 = 0.12915390729904175
# Iteration 0 - Updated Dino MSE for Image 133 = 0.1297365128993988
# Iteration 0 - Difference = 0.0005826056003570557
#
# Iteration 0 - Original Dino MSE for Image 134 = 0.3247731626033783
# Iteration 0 - Updated Dino MSE for Image 134 = 0.2999977767467499
# Iteration 0 - Difference = -0.024775385856628418
#
# Iteration 0 - Original Dino MSE for Image 135 = 0.2889223098754883
# Iteration 0 - Updated Dino MSE for Image 135 = 0.28110015392303467
# Iteration 0 - Difference = -0.007822155952453613
#
# Iteration 0 - Original Dino MSE for Image 136 = 0.2855879068374634
# Iteration 0 - Updated Dino MSE for Image 136 = 0.23967726528644562
# Iteration 0 - Difference = -0.04591064155101776
#
# Iteration 0 - Original Dino MSE for Image 137 = 0.8124271035194397
# Iteration 0 - Updated Dino MSE for Image 137 = 0.7906805276870728
# Iteration 0 - Difference = -0.021746575832366943
#
# Iteration 0 - Original Dino MSE for Image 138 = 0.7601954340934753
# Iteration 0 - Updated Dino MSE for Image 138 = 0.6346668601036072
# Iteration 0 - Difference = -0.12552857398986816
#
# Iteration 0 - Original Dino MSE for Image 139 = 0.6562538743019104
# Iteration 0 - Updated Dino MSE for Image 139 = 0.6470422744750977
# Iteration 0 - Difference = -0.009211599826812744
#
# Iteration 0 - Original Dino MSE for Image 140 = 0.652202308177948
# Iteration 0 - Updated Dino MSE for Image 140 = 0.5658700466156006
# Iteration 0 - Difference = -0.08633226156234741
#
# Iteration 0 - Original Dino MSE for Image 141 = 0.6756793856620789
# Iteration 0 - Updated Dino MSE for Image 141 = 0.6071308255195618
# Iteration 0 - Difference = -0.06854856014251709
#
# Iteration 0 - Original Dino MSE for Image 142 = 0.242466002702713
# Iteration 0 - Updated Dino MSE for Image 142 = 0.22630968689918518
# Iteration 0 - Difference = -0.016156315803527832
#
# Iteration 0 - Original Dino MSE for Image 143 = 0.38986071944236755
# Iteration 0 - Updated Dino MSE for Image 143 = 0.3044459819793701
# Iteration 0 - Difference = -0.08541473746299744
#
# Iteration 0 - Original Dino MSE for Image 144 = 0.2977522313594818
# Iteration 0 - Updated Dino MSE for Image 144 = 0.27439579367637634
# Iteration 0 - Difference = -0.02335643768310547
#
# Iteration 0 - Original Dino MSE for Image 145 = 0.3501909077167511
# Iteration 0 - Updated Dino MSE for Image 145 = 0.2950192391872406
# Iteration 0 - Difference = -0.0551716685295105
#
# Iteration 0 - Original Dino MSE for Image 146 = 0.3875596225261688
# Iteration 0 - Updated Dino MSE for Image 146 = 0.34425127506256104
# Iteration 0 - Difference = -0.04330834746360779
#
# Iteration 0 - Original Dino MSE for Image 147 = 0.25724104046821594
# Iteration 0 - Updated Dino MSE for Image 147 = 0.2545676827430725
# Iteration 0 - Difference = -0.0026733577251434326
#
# Iteration 0 - Original Dino MSE for Image 148 = 0.18382957577705383
# Iteration 0 - Updated Dino MSE for Image 148 = 0.1961905062198639
# Iteration 0 - Difference = 0.012360930442810059
#
# Iteration 0 - Original Dino MSE for Image 149 = 0.18920500576496124
# Iteration 0 - Updated Dino MSE for Image 149 = 0.1872258484363556
# Iteration 0 - Difference = -0.001979157328605652
#
# Iteration 0 - Original Dino MSE for Image 150 = 0.3031584322452545
# Iteration 0 - Updated Dino MSE for Image 150 = 0.23967628180980682
# Iteration 0 - Difference = -0.06348215043544769
#
# Iteration 0 - Original Dino MSE for Image 151 = 0.23087187111377716
# Iteration 0 - Updated Dino MSE for Image 151 = 0.23432311415672302
# Iteration 0 - Difference = 0.003451243042945862
#
# Iteration 0 - Original Dino MSE for Image 152 = 0.19797676801681519
# Iteration 0 - Updated Dino MSE for Image 152 = 0.18094491958618164
# Iteration 0 - Difference = -0.017031848430633545
#
# Iteration 0 - Original Dino MSE for Image 153 = 0.19155363738536835
# Iteration 0 - Updated Dino MSE for Image 153 = 0.1924285739660263
# Iteration 0 - Difference = 0.000874936580657959
#
# Iteration 0 - Original Dino MSE for Image 154 = 0.14361590147018433
# Iteration 0 - Updated Dino MSE for Image 154 = 0.15167278051376343
# Iteration 0 - Difference = 0.008056879043579102
#
# Iteration 0 - Original Dino MSE for Image 155 = 0.102487713098526
# Iteration 0 - Updated Dino MSE for Image 155 = 0.10944055020809174
# Iteration 0 - Difference = 0.006952837109565735
#
# Iteration 0 - Original Dino MSE for Image 156 = 0.1443644016981125
# Iteration 0 - Updated Dino MSE for Image 156 = 0.1390419453382492
# Iteration 0 - Difference = -0.005322456359863281
#
# Iteration 0 - Original Dino MSE for Image 157 = 0.08446017652750015
# Iteration 0 - Updated Dino MSE for Image 157 = 0.08562926203012466
# Iteration 0 - Difference = 0.0011690855026245117
#
# Iteration 0 - Original Dino MSE for Image 158 = 0.10885170102119446
# Iteration 0 - Updated Dino MSE for Image 158 = 0.10714840888977051
# Iteration 0 - Difference = -0.0017032921314239502
#
# Iteration 0 - Original Dino MSE for Image 159 = 0.10834140330553055
# Iteration 0 - Updated Dino MSE for Image 159 = 0.10294098407030106
# Iteration 0 - Difference = -0.005400419235229492
#
# Iteration 0 - Original Dino MSE for Image 160 = 0.10560132563114166
# Iteration 0 - Updated Dino MSE for Image 160 = 0.10261686891317368
# Iteration 0 - Difference = -0.002984456717967987
#
# Iteration 0 - Original Dino MSE for Image 161 = 0.13844461739063263
# Iteration 0 - Updated Dino MSE for Image 161 = 0.13658809661865234
# Iteration 0 - Difference = -0.0018565207719802856
#
# Iteration 0 - Original Dino MSE for Image 162 = 0.09504706412553787
# Iteration 0 - Updated Dino MSE for Image 162 = 0.09621427208185196
# Iteration 0 - Difference = 0.001167207956314087
#
# Iteration 0 - Original Dino MSE for Image 163 = 0.11019369214773178
# Iteration 0 - Updated Dino MSE for Image 163 = 0.1027134507894516
# Iteration 0 - Difference = -0.007480241358280182
#
# Iteration 0 - Original Dino MSE for Image 164 = 0.11348199099302292
# Iteration 0 - Updated Dino MSE for Image 164 = 0.10556045174598694
# Iteration 0 - Difference = -0.00792153924703598
#
# Iteration 0 - Original Dino MSE for Image 165 = 0.11155905574560165
# Iteration 0 - Updated Dino MSE for Image 165 = 0.11350981891155243
# Iteration 0 - Difference = 0.0019507631659507751
#
# Iteration 0 - Original Dino MSE for Image 166 = 0.11306741833686829
# Iteration 0 - Updated Dino MSE for Image 166 = 0.11062419414520264
# Iteration 0 - Difference = -0.0024432241916656494
#
# Iteration 0 - Original Dino MSE for Image 167 = 0.15218746662139893
# Iteration 0 - Updated Dino MSE for Image 167 = 0.13902981579303741
# Iteration 0 - Difference = -0.013157650828361511
#
# Iteration 0 - Original Dino MSE for Image 168 = 0.14118468761444092
# Iteration 0 - Updated Dino MSE for Image 168 = 0.13763920962810516
# Iteration 0 - Difference = -0.0035454779863357544
#
# Iteration 0 - Original Dino MSE for Image 169 = 0.13797958195209503
# Iteration 0 - Updated Dino MSE for Image 169 = 0.1373150646686554
# Iteration 0 - Difference = -0.0006645172834396362
#
# Iteration 0 - Original Dino MSE for Image 170 = 0.1917581856250763
# Iteration 0 - Updated Dino MSE for Image 170 = 0.18878576159477234
# Iteration 0 - Difference = -0.002972424030303955
#
# Iteration 0 - Original Dino MSE for Image 171 = 0.16531561315059662
# Iteration 0 - Updated Dino MSE for Image 171 = 0.171726256608963
# Iteration 0 - Difference = 0.006410643458366394
#
# Iteration 0 - Original Dino MSE for Image 172 = 0.08849620819091797
# Iteration 0 - Updated Dino MSE for Image 172 = 0.10207748413085938
# Iteration 0 - Difference = 0.013581275939941406
#
# Iteration 0 - Original Dino MSE for Image 173 = 0.14509227871894836
# Iteration 0 - Updated Dino MSE for Image 173 = 0.12775902450084686
# Iteration 0 - Difference = -0.0173332542181015
#
# Iteration 0 - Original Dino MSE for Image 174 = 0.12337591499090195
# Iteration 0 - Updated Dino MSE for Image 174 = 0.14261162281036377
# Iteration 0 - Difference = 0.019235707819461823
#
# Iteration 0 - Original Dino MSE for Image 175 = 0.14564937353134155
# Iteration 0 - Updated Dino MSE for Image 175 = 0.1356559693813324
# Iteration 0 - Difference = -0.009993404150009155
#
# Iteration 0 - Original Dino MSE for Image 176 = 0.25784075260162354
# Iteration 0 - Updated Dino MSE for Image 176 = 0.2220648229122162
# Iteration 0 - Difference = -0.03577592968940735
#
# Iteration 0 - Original Dino MSE for Image 177 = 0.17020927369594574
# Iteration 0 - Updated Dino MSE for Image 177 = 0.19297760725021362
# Iteration 0 - Difference = 0.022768333554267883
#
# Iteration 0 - Original Dino MSE for Image 178 = 0.21767127513885498
# Iteration 0 - Updated Dino MSE for Image 178 = 0.1907019317150116
# Iteration 0 - Difference = -0.026969343423843384
#
# Iteration 0 - Original Dino MSE for Image 179 = 0.24346905946731567
# Iteration 0 - Updated Dino MSE for Image 179 = 0.244797021150589
# Iteration 0 - Difference = 0.0013279616832733154
#
# Iteration 0 - Original Dino MSE for Image 180 = 0.13883589208126068
# Iteration 0 - Updated Dino MSE for Image 180 = 0.16381727159023285
# Iteration 0 - Difference = 0.024981379508972168
#
# Iteration 0 - Original Dino MSE for Image 181 = 0.14172759652137756
# Iteration 0 - Updated Dino MSE for Image 181 = 0.1421550065279007
# Iteration 0 - Difference = 0.0004274100065231323
#
# Iteration 0 - Original Dino MSE for Image 182 = 0.13265861570835114
# Iteration 0 - Updated Dino MSE for Image 182 = 0.1323874443769455
# Iteration 0 - Difference = -0.00027117133140563965
#
# Iteration 0 - Original Dino MSE for Image 183 = 0.19038446247577667
# Iteration 0 - Updated Dino MSE for Image 183 = 0.17605090141296387
# Iteration 0 - Difference = -0.014333561062812805
#
# Iteration 0 - Original Dino MSE for Image 184 = 0.1320466250181198
# Iteration 0 - Updated Dino MSE for Image 184 = 0.13878992199897766
# Iteration 0 - Difference = 0.006743296980857849
#
# Iteration 0 - Original Dino MSE for Image 185 = 0.14023199677467346
# Iteration 0 - Updated Dino MSE for Image 185 = 0.13360773026943207
# Iteration 0 - Difference = -0.006624266505241394
#
# Iteration 0 - Original Dino MSE for Image 186 = 0.15982909500598907
# Iteration 0 - Updated Dino MSE for Image 186 = 0.15577226877212524
# Iteration 0 - Difference = -0.004056826233863831
#
# Iteration 0 - Original Dino MSE for Image 187 = 0.13159631192684174
# Iteration 0 - Updated Dino MSE for Image 187 = 0.1337691694498062
# Iteration 0 - Difference = 0.0021728575229644775
#
# Iteration 0 - Original Dino MSE for Image 188 = 0.1271219700574875
# Iteration 0 - Updated Dino MSE for Image 188 = 0.13477036356925964
# Iteration 0 - Difference = 0.007648393511772156
#
# Iteration 0 - Original Dino MSE for Image 189 = 0.07879163324832916
# Iteration 0 - Updated Dino MSE for Image 189 = 0.07966306060552597
# Iteration 0 - Difference = 0.0008714273571968079
#
# Iteration 0 - Original Dino MSE for Image 190 = 0.07901033014059067
# Iteration 0 - Updated Dino MSE for Image 190 = 0.08584684878587723
# Iteration 0 - Difference = 0.00683651864528656
#
# Iteration 0 - Original Dino MSE for Image 191 = 0.14081914722919464
# Iteration 0 - Updated Dino MSE for Image 191 = 0.11325482279062271
# Iteration 0 - Difference = -0.02756432443857193
#
# Iteration 0 - Original Dino MSE for Image 192 = 0.15144087374210358
# Iteration 0 - Updated Dino MSE for Image 192 = 0.15233220160007477
# Iteration 0 - Difference = 0.0008913278579711914
#
# Iteration 0 - Original Dino MSE for Image 193 = 0.23929420113563538
# Iteration 0 - Updated Dino MSE for Image 193 = 0.20004281401634216
# Iteration 0 - Difference = -0.03925138711929321
#
# Iteration 0 - Original Dino MSE for Image 194 = 0.12305898219347
# Iteration 0 - Updated Dino MSE for Image 194 = 0.1422528177499771
# Iteration 0 - Difference = 0.01919383555650711
#
# Iteration 0 - Original Dino MSE for Image 195 = 0.2875112295150757
# Iteration 0 - Updated Dino MSE for Image 195 = 0.24432125687599182
# Iteration 0 - Difference = -0.04318997263908386
#
# Iteration 0 - Original Dino MSE for Image 196 = 0.1998572051525116
# Iteration 0 - Updated Dino MSE for Image 196 = 0.2278207540512085
# Iteration 0 - Difference = 0.0279635488986969
#
# Iteration 0 - Original Dino MSE for Image 197 = 0.15094521641731262
# Iteration 0 - Updated Dino MSE for Image 197 = 0.16226182878017426
# Iteration 0 - Difference = 0.011316612362861633
#
# Iteration 0 - Original Dino MSE for Image 198 = 0.12675724923610687
# Iteration 0 - Updated Dino MSE for Image 198 = 0.12131957709789276
# Iteration 0 - Difference = -0.005437672138214111
#
# Iteration 0 - Original Dino MSE for Image 199 = 0.19046443700790405
# Iteration 0 - Updated Dino MSE for Image 199 = 0.18691106140613556
# Iteration 0 - Difference = -0.0035533756017684937
#
# Iteration 0 - Original Dino MSE for Image 200 = 0.22360128164291382
# Iteration 0 - Updated Dino MSE for Image 200 = 0.19778834283351898
# Iteration 0 - Difference = -0.025812938809394836
#
# Iteration 0 - Original Dino MSE for Image 201 = 0.23920570313930511
# Iteration 0 - Updated Dino MSE for Image 201 = 0.2453126311302185
# Iteration 0 - Difference = 0.006106927990913391
#
# Iteration 0 - Original Dino MSE for Image 202 = 0.17063117027282715
# Iteration 0 - Updated Dino MSE for Image 202 = 0.18179255723953247
# Iteration 0 - Difference = 0.011161386966705322
#
# Iteration 0 - Original Dino MSE for Image 203 = 0.18090122938156128
# Iteration 0 - Updated Dino MSE for Image 203 = 0.1855909377336502
# Iteration 0 - Difference = 0.004689708352088928
#
# Iteration 0 - Original Dino MSE for Image 204 = 0.154914990067482
# Iteration 0 - Updated Dino MSE for Image 204 = 0.13577283918857574
# Iteration 0 - Difference = -0.01914215087890625
#
# Iteration 0 - Original Dino MSE for Image 205 = 0.1952926367521286
# Iteration 0 - Updated Dino MSE for Image 205 = 0.17481812834739685
# Iteration 0 - Difference = -0.02047450840473175
#
# Iteration 0 - Original Dino MSE for Image 206 = 0.1634952872991562
# Iteration 0 - Updated Dino MSE for Image 206 = 0.18212080001831055
# Iteration 0 - Difference = 0.018625512719154358
#
# Iteration 0 - Original Dino MSE for Image 207 = 0.12500855326652527
# Iteration 0 - Updated Dino MSE for Image 207 = 0.1427435427904129
# Iteration 0 - Difference = 0.017734989523887634
#
# Iteration 0 - Original Dino MSE for Image 208 = 0.11167014390230179
# Iteration 0 - Updated Dino MSE for Image 208 = 0.10683199018239975
# Iteration 0 - Difference = -0.004838153719902039
#
# Iteration 0 - Original Dino MSE for Image 209 = 0.13343410193920135
# Iteration 0 - Updated Dino MSE for Image 209 = 0.13585911691188812
# Iteration 0 - Difference = 0.0024250149726867676
#
# Iteration 0 - Original Dino MSE for Image 210 = 0.09471838176250458
# Iteration 0 - Updated Dino MSE for Image 210 = 0.09681094437837601
# Iteration 0 - Difference = 0.0020925626158714294
#
# Iteration 0 - Original Dino MSE for Image 211 = 0.14251407980918884
# Iteration 0 - Updated Dino MSE for Image 211 = 0.13950833678245544
# Iteration 0 - Difference = -0.0030057430267333984
#
# Iteration 0 - Original Dino MSE for Image 212 = 0.14049208164215088
# Iteration 0 - Updated Dino MSE for Image 212 = 0.15228456258773804
# Iteration 0 - Difference = 0.011792480945587158
#
# Iteration 0 - Original Dino MSE for Image 213 = 0.1418532133102417
# Iteration 0 - Updated Dino MSE for Image 213 = 0.13479091227054596
# Iteration 0 - Difference = -0.00706230103969574
#
# Iteration 0 - Original Dino MSE for Image 214 = 0.09348075091838837
# Iteration 0 - Updated Dino MSE for Image 214 = 0.0958881825208664
# Iteration 0 - Difference = 0.0024074316024780273
#
# Iteration 0 - Original Dino MSE for Image 215 = 0.13700443506240845
# Iteration 0 - Updated Dino MSE for Image 215 = 0.13089950382709503
# Iteration 0 - Difference = -0.0061049312353134155
#
# Iteration 0 - Original Dino MSE for Image 216 = 0.09411496669054031
# Iteration 0 - Updated Dino MSE for Image 216 = 0.09876933693885803
# Iteration 0 - Difference = 0.0046543702483177185
#
# Iteration 0 - Original Dino MSE for Image 217 = 0.1290675550699234
# Iteration 0 - Updated Dino MSE for Image 217 = 0.13373272120952606
# Iteration 0 - Difference = 0.004665166139602661
#
# Iteration 0 - Original Dino MSE for Image 218 = 0.15505041182041168
# Iteration 0 - Updated Dino MSE for Image 218 = 0.15470236539840698
# Iteration 0 - Difference = -0.0003480464220046997
#
# Iteration 0 - Original Dino MSE for Image 219 = 0.11676632612943649
# Iteration 0 - Updated Dino MSE for Image 219 = 0.12005003541707993
# Iteration 0 - Difference = 0.0032837092876434326
#
# Iteration 0 - Original Dino MSE for Image 220 = 0.1044408529996872
# Iteration 0 - Updated Dino MSE for Image 220 = 0.10559035837650299
# Iteration 0 - Difference = 0.001149505376815796
#
# Iteration 0 - Original Dino MSE for Image 221 = 0.07874190807342529
# Iteration 0 - Updated Dino MSE for Image 221 = 0.07374966889619827
# Iteration 0 - Difference = -0.00499223917722702
#
# Iteration 0 - Original Dino MSE for Image 222 = 0.06904415786266327
# Iteration 0 - Updated Dino MSE for Image 222 = 0.0665443167090416
# Iteration 0 - Difference = -0.0024998411536216736
#
# Iteration 0 - Original Dino MSE for Image 223 = 0.11391329020261765
# Iteration 0 - Updated Dino MSE for Image 223 = 0.10494434088468552
# Iteration 0 - Difference = -0.008968949317932129
#
# Iteration 0 - Original Dino MSE for Image 224 = 0.1086321696639061
# Iteration 0 - Updated Dino MSE for Image 224 = 0.11035420000553131
# Iteration 0 - Difference = 0.0017220303416252136
#
# Iteration 0 - Original Dino MSE for Image 225 = 0.11553148180246353
# Iteration 0 - Updated Dino MSE for Image 225 = 0.11879340559244156
# Iteration 0 - Difference = 0.0032619237899780273
#
# Iteration 0 - Original Dino MSE for Image 226 = 0.09225498139858246
# Iteration 0 - Updated Dino MSE for Image 226 = 0.10756753385066986
# Iteration 0 - Difference = 0.015312552452087402
#
# Iteration 0 - Original Dino MSE for Image 227 = 0.08013153821229935
# Iteration 0 - Updated Dino MSE for Image 227 = 0.07614767551422119
# Iteration 0 - Difference = -0.0039838626980781555
#
# Iteration 0 - Original Dino MSE for Image 228 = 0.11195863038301468
# Iteration 0 - Updated Dino MSE for Image 228 = 0.1147676631808281
# Iteration 0 - Difference = 0.0028090327978134155
#
# Iteration 0 - Original Dino MSE for Image 229 = 0.09325537830591202
# Iteration 0 - Updated Dino MSE for Image 229 = 0.09984641522169113
# Iteration 0 - Difference = 0.006591036915779114
#
# Iteration 0 - Original Dino MSE for Image 230 = 0.11607268452644348
# Iteration 0 - Updated Dino MSE for Image 230 = 0.11268211156129837
# Iteration 0 - Difference = -0.003390572965145111
#
# Iteration 0 - Original Dino MSE for Image 231 = 0.07878141105175018
# Iteration 0 - Updated Dino MSE for Image 231 = 0.08391691744327545
# Iteration 0 - Difference = 0.0051355063915252686
#
# Iteration 0 - Original Dino MSE for Image 232 = 0.05607675388455391
# Iteration 0 - Updated Dino MSE for Image 232 = 0.06069087237119675
# Iteration 0 - Difference = 0.0046141184866428375
#
# Iteration 0 - Original Dino MSE for Image 233 = 0.058783598244190216
# Iteration 0 - Updated Dino MSE for Image 233 = 0.056874193251132965
# Iteration 0 - Difference = -0.001909404993057251
#
# Iteration 0 - Original Dino MSE for Image 234 = 0.055148202925920486
# Iteration 0 - Updated Dino MSE for Image 234 = 0.05341825634241104
# Iteration 0 - Difference = -0.0017299465835094452
#
# Iteration 0 - Original Dino MSE for Image 235 = 0.06777624785900116
# Iteration 0 - Updated Dino MSE for Image 235 = 0.06934954971075058
# Iteration 0 - Difference = 0.0015733018517494202
#
# Iteration 0 - Original Dino MSE for Image 236 = 0.1208825409412384
# Iteration 0 - Updated Dino MSE for Image 236 = 0.12932100892066956
# Iteration 0 - Difference = 0.008438467979431152
#
# Iteration 0 - Original Dino MSE for Image 237 = 0.1343642920255661
# Iteration 0 - Updated Dino MSE for Image 237 = 0.13642945885658264
# Iteration 0 - Difference = 0.0020651668310165405
#
# Iteration 0 - Original Dino MSE for Image 238 = 0.06350774317979813
# Iteration 0 - Updated Dino MSE for Image 238 = 0.07090909034013748
# Iteration 0 - Difference = 0.0074013471603393555
#
# Iteration 0 - Original Dino MSE for Image 239 = 0.048818737268447876
# Iteration 0 - Updated Dino MSE for Image 239 = 0.04262612387537956
# Iteration 0 - Difference = -0.006192613393068314
#
# Iteration 0 - Original Dino MSE for Image 240 = 0.023426877334713936
# Iteration 0 - Updated Dino MSE for Image 240 = 0.028606941923499107
# Iteration 0 - Difference = 0.0051800645887851715
#
# Iteration 0 - Original Dino MSE for Image 241 = 0.028108544647693634
# Iteration 0 - Updated Dino MSE for Image 241 = 0.02490261010825634
# Iteration 0 - Difference = -0.003205934539437294
#
# Iteration 0 - Original Dino MSE for Image 242 = 0.01958998665213585
# Iteration 0 - Updated Dino MSE for Image 242 = 0.021042225882411003
# Iteration 0 - Difference = 0.0014522392302751541
#
# Iteration 0 - Original Dino MSE for Image 243 = 0.029491405934095383
# Iteration 0 - Updated Dino MSE for Image 243 = 0.026533814147114754
# Iteration 0 - Difference = -0.002957591786980629
#
# Iteration 0 - Original Dino MSE for Image 244 = 0.04964442923665047
# Iteration 0 - Updated Dino MSE for Image 244 = 0.0444687083363533
# Iteration 0 - Difference = -0.005175720900297165
#
# Iteration 0 - Original Dino MSE for Image 245 = 0.03438912704586983
# Iteration 0 - Updated Dino MSE for Image 245 = 0.03871682658791542
# Iteration 0 - Difference = 0.004327699542045593
#
# Iteration 0 - Original Dino MSE for Image 246 = 0.048052385449409485
# Iteration 0 - Updated Dino MSE for Image 246 = 0.04234382510185242
# Iteration 0 - Difference = -0.005708560347557068
#
# Iteration 0 - Original Dino MSE for Image 247 = 0.04539152607321739
# Iteration 0 - Updated Dino MSE for Image 247 = 0.050269365310668945
# Iteration 0 - Difference = 0.004877839237451553
#
# Iteration 0 - Original Dino MSE for Image 248 = 0.030026135966181755
# Iteration 0 - Updated Dino MSE for Image 248 = 0.034500133246183395
# Iteration 0 - Difference = 0.00447399728000164
#
# Iteration 0 - Original Dino MSE for Image 249 = 0.043884214013814926
# Iteration 0 - Updated Dino MSE for Image 249 = 0.03823516145348549
# Iteration 0 - Difference = -0.005649052560329437
#
# Iteration 0 - Original Dino MSE for Image 250 = 0.06372496485710144
# Iteration 0 - Updated Dino MSE for Image 250 = 0.05592561513185501
# Iteration 0 - Difference = -0.0077993497252464294
#
# Iteration 0 - Original Dino MSE for Image 251 = 0.0986725315451622
# Iteration 0 - Updated Dino MSE for Image 251 = 0.08535738289356232
# Iteration 0 - Difference = -0.013315148651599884
#
# Iteration 0 - Original Dino MSE for Image 252 = 0.07823262363672256
# Iteration 0 - Updated Dino MSE for Image 252 = 0.0834684744477272
# Iteration 0 - Difference = 0.005235850811004639
#
# Iteration 0 - Original Dino MSE for Image 253 = 0.15012194216251373
# Iteration 0 - Updated Dino MSE for Image 253 = 0.12380296736955643
# Iteration 0 - Difference = -0.026318974792957306
#
# Iteration 0 - Original Dino MSE for Image 254 = 0.058310531079769135
# Iteration 0 - Updated Dino MSE for Image 254 = 0.0766245424747467
# Iteration 0 - Difference = 0.01831401139497757
#
# Iteration 0 - Original Dino MSE for Image 255 = 0.07352995127439499
# Iteration 0 - Updated Dino MSE for Image 255 = 0.06824176758527756
# Iteration 0 - Difference = -0.005288183689117432
#
# Iteration 0 - Original Dino MSE for Image 256 = 0.02617494761943817
# Iteration 0 - Updated Dino MSE for Image 256 = 0.03658837080001831
# Iteration 0 - Difference = 0.01041342318058014
#
# Iteration 0 - Original Dino MSE for Image 257 = 0.03403748571872711
# Iteration 0 - Updated Dino MSE for Image 257 = 0.03138746693730354
# Iteration 0 - Difference = -0.0026500187814235687
#
# Iteration 0 - Original Dino MSE for Image 258 = 0.04138430580496788
# Iteration 0 - Updated Dino MSE for Image 258 = 0.042782850563526154
# Iteration 0 - Difference = 0.0013985447585582733
#
# Iteration 0 - Original Dino MSE for Image 259 = 0.04779330641031265
# Iteration 0 - Updated Dino MSE for Image 259 = 0.0438249409198761
# Iteration 0 - Difference = -0.003968365490436554
#
# Iteration 0 - Original Dino MSE for Image 260 = 0.0925666019320488
# Iteration 0 - Updated Dino MSE for Image 260 = 0.07284437119960785
# Iteration 0 - Difference = -0.01972223073244095
#
# Iteration 0 - Original Dino MSE for Image 261 = 0.03757007420063019
# Iteration 0 - Updated Dino MSE for Image 261 = 0.04549255222082138
# Iteration 0 - Difference = 0.007922478020191193
#
# Iteration 0 - Original Dino MSE for Image 262 = 0.026416044682264328
# Iteration 0 - Updated Dino MSE for Image 262 = 0.025955580174922943
# Iteration 0 - Difference = -0.0004604645073413849
#
# Iteration 0 - Original Dino MSE for Image 263 = 0.02799687162041664
# Iteration 0 - Updated Dino MSE for Image 263 = 0.026246029883623123
# Iteration 0 - Difference = -0.001750841736793518
#
# Iteration 0 - Original Dino MSE for Image 264 = 0.05837344005703926
# Iteration 0 - Updated Dino MSE for Image 264 = 0.0488039031624794
# Iteration 0 - Difference = -0.00956953689455986
#
# Iteration 0 - Original Dino MSE for Image 265 = 0.06169440224766731
# Iteration 0 - Updated Dino MSE for Image 265 = 0.053952157497406006
# Iteration 0 - Difference = -0.007742244750261307
#
# Iteration 0 - Original Dino MSE for Image 266 = 0.05811457708477974
# Iteration 0 - Updated Dino MSE for Image 266 = 0.06297190487384796
# Iteration 0 - Difference = 0.004857327789068222
#
# Iteration 0 - Original Dino MSE for Image 267 = 0.07371163368225098
# Iteration 0 - Updated Dino MSE for Image 267 = 0.08940903842449188
# Iteration 0 - Difference = 0.015697404742240906
#
# Iteration 0 - Original Dino MSE for Image 268 = 0.06930267065763474
# Iteration 0 - Updated Dino MSE for Image 268 = 0.07471062242984772
# Iteration 0 - Difference = 0.005407951772212982
#
# Iteration 0 - Original Dino MSE for Image 269 = 0.0768146738409996
# Iteration 0 - Updated Dino MSE for Image 269 = 0.07652264088392258
# Iteration 0 - Difference = -0.00029203295707702637
#
# Iteration 0 - Original Dino MSE for Image 270 = 0.09771155565977097
# Iteration 0 - Updated Dino MSE for Image 270 = 0.09907166659832001
# Iteration 0 - Difference = 0.0013601109385490417
#
# Iteration 0 - Original Dino MSE for Image 271 = 0.1062169075012207
# Iteration 0 - Updated Dino MSE for Image 271 = 0.1051812693476677
# Iteration 0 - Difference = -0.001035638153553009
#
# Iteration 0 - Original Dino MSE for Image 272 = 0.12050988525152206
# Iteration 0 - Updated Dino MSE for Image 272 = 0.1209346279501915
# Iteration 0 - Difference = 0.0004247426986694336
#
# Iteration 0 - Original Dino MSE for Image 273 = 0.09029463678598404
# Iteration 0 - Updated Dino MSE for Image 273 = 0.09647621959447861
# Iteration 0 - Difference = 0.006181582808494568
#
# Iteration 0 - Original Dino MSE for Image 274 = 0.1030021607875824
# Iteration 0 - Updated Dino MSE for Image 274 = 0.11897172778844833
# Iteration 0 - Difference = 0.015969567000865936
#
# Iteration 0 - Original Dino MSE for Image 275 = 0.08943481743335724
# Iteration 0 - Updated Dino MSE for Image 275 = 0.08827292919158936
# Iteration 0 - Difference = -0.0011618882417678833
#
# Iteration 0 - Original Dino MSE for Image 276 = 0.09782162308692932
# Iteration 0 - Updated Dino MSE for Image 276 = 0.08840996772050858
# Iteration 0 - Difference = -0.009411655366420746
#
# Iteration 0 - Original Dino MSE for Image 277 = 0.11360804736614227
# Iteration 0 - Updated Dino MSE for Image 277 = 0.10764384269714355
# Iteration 0 - Difference = -0.005964204668998718
#
# Iteration 0 - Original Dino MSE for Image 278 = 0.0949174016714096
# Iteration 0 - Updated Dino MSE for Image 278 = 0.09458208084106445
# Iteration 0 - Difference = -0.0003353208303451538
#
# Iteration 0 - Original Dino MSE for Image 279 = 0.11440544575452805
# Iteration 0 - Updated Dino MSE for Image 279 = 0.11188546568155289
# Iteration 0 - Difference = -0.0025199800729751587
#
# Iteration 0 - Original Dino MSE for Image 280 = 0.14300304651260376
# Iteration 0 - Updated Dino MSE for Image 280 = 0.1824241280555725
# Iteration 0 - Difference = 0.03942108154296875
#
# Iteration 0 - Mean Original DINO MSE Across 281 Images = 0.1695290356874466
# Iteration 0 - Mean Updated DINO MSE Across 281 Images = 0.1614178717136383
# Iteration 0 - Mean Difference Across 281 Images = -0.0081111378967762, (-4.784512495977595 percent change relative to Vanilla DINOv2)

# %% [markdown]
# _Run this block to test the accuracy of the Iteration 1 Pipeline, as compared to the Vanilla DINOv2 model._

# %%
# Accuracy Test - Iteration 1

import cv2
import matplotlib.pyplot as plt
import numpy as np

# %cd '/content/'

rho = 0.83

image_height = 480
image_width = 640
ground_truth_depth = np.zeros((num_images, image_height, image_width))
original_dino_depth_map = torch.zeros((num_images, image_height, image_width))
updated_dino_depth_map = torch.zeros((num_images, image_height, image_width))
original_dino_mse = torch.zeros(num_images)
updated_dino_mse = torch.zeros(num_images)
difference = torch.zeros(num_images)
images = []
grayscale_images = []

for i in range(num_images):
    images.append(cv2.imread(str(i+1) + '.jpg'))
    grayscale_images.append(cv2.imread(str(i+1) + '.jpg', 0))
    ground_truth_depth[i] = 10.0 * np.array(Image.open(str(i+1) + '.png')).astype(float)/255.0

feature_algorithm = cv2.ORB_create(nfeatures=500)
transform = make_depth_transform()

for i in range(num_images):
    transformed_image = transform(images[i])
    batch = transformed_image.unsqueeze(0).cuda()

    with torch.no_grad():
        original_dino_depth_map[i] = model.whole_inference(batch, img_meta=None, rescale=True).squeeze()

    masked_true_depths = torch.tensor(ground_truth_depth[i][ground_truth_depth[i] > 0.0])
    original_masked_dino_depths = torch.tensor(original_dino_depth_map[i][ground_truth_depth[i] > 0.0])

    original_dino_mse[i] = F.mse_loss(original_masked_dino_depths, masked_true_depths)

    print("\nIteration 1 - Original Dino MSE for Image " + str(i) + " = " + str(original_dino_mse[i].item()))

    if i == 0:
        updated_dino_mse[i] = original_dino_mse[i]
        difference[i] = 0.0
    else:
        shift_x, shift_y = cv2.phaseCorrelate(np.float32(grayscale_images[i-1]), np.float32(grayscale_images[i]))[0]

        shift_x = round(shift_x)
        shift_y = round(shift_y)

        if np.abs(shift_x) < 100 and np.abs(shift_y) < 100:
            updated_dino_depth_map[i] = original_dino_depth_map[i].clone()
            if shift_x >= 0 and shift_y >= 0:
                updated_dino_depth_map[i, shift_y:, shift_x:] = rho * original_dino_depth_map[i, shift_y:, shift_x:] + (1 - rho) * original_dino_depth_map[i-1, :image_height-shift_y, :image_width-shift_x]
            elif shift_x >= 0 and shift_y < 0:
                updated_dino_depth_map[i, :image_height+shift_y, shift_x:] = rho * original_dino_depth_map[i, :image_height+shift_y, shift_x:] + (1 - rho) * original_dino_depth_map[i-1, -shift_y:, :image_width-shift_x]
            elif shift_x < 0 and shift_y >= 0:
                updated_dino_depth_map[i, shift_y:, :image_width+shift_x] = rho * original_dino_depth_map[i, shift_y:, :image_width+shift_x] + (1 - rho) * original_dino_depth_map[i-1, :image_height-shift_y, -shift_x:]
            else:
                updated_dino_depth_map[i, :image_height+shift_y, :image_width+shift_x] = rho * original_dino_depth_map[i, :image_height+shift_y, :image_width+shift_x] + (1 - rho) * original_dino_depth_map[i-1, -shift_y:, -shift_x:]

            updated_masked_dino_depths = torch.tensor(updated_dino_depth_map[i][ground_truth_depth[i] > 0.0])

            updated_dino_mse[i] = F.mse_loss(updated_masked_dino_depths, masked_true_depths)

            print("Iteration 1 - Updated Dino MSE for Image " + str(i) + " = " + str(updated_dino_mse[i].item()))

            difference[i] = updated_dino_mse[i].item() - original_dino_mse[i].item()

            print("Iteration 1 - Difference = " + str(difference[i].item()))
        else:
            updated_dino_mse[i] = original_dino_mse[i]
            difference[i] = 0.0

print("\nIteration 0 - Mean Original DINO MSE Across " + str(num_images) + " Images = " + str(torch.mean(original_dino_mse).item()))
print("Iteration 0 - Mean Updated DINO MSE Across " + str(num_images) + " Images = " + str(torch.mean(updated_dino_mse).item()))
print("Iteration 0 - Mean Difference Across " + str(num_images) + " Images = " + str(torch.mean(difference).item()) + ", (" + str(torch.mean(difference).item()/torch.mean(original_dino_mse).item()*100) + " percent change relative to Vanilla DINOv2)")
# Out:
# /content
# <ipython-input-48-dc500f3a5990>:38: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   original_masked_dino_depths = torch.tensor(original_dino_depth_map[i][ground_truth_depth[i] > 0.0])
# <ipython-input-48-dc500f3a5990>:64: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   updated_masked_dino_depths = torch.tensor(updated_dino_depth_map[i][ground_truth_depth[i] > 0.0])
# Iteration 1 - Original Dino MSE for Image 0 = 0.4600278437137604
#
# Iteration 1 - Original Dino MSE for Image 1 = 0.33338451385498047
# Iteration 1 - Updated Dino MSE for Image 1 = 0.3407396674156189
# Iteration 1 - Difference = 0.007355153560638428
#
# Iteration 1 - Original Dino MSE for Image 2 = 0.3002174198627472
# Iteration 1 - Updated Dino MSE for Image 2 = 0.27350690960884094
# Iteration 1 - Difference = -0.02671051025390625
#
# Iteration 1 - Original Dino MSE for Image 3 = 0.23217007517814636
# Iteration 1 - Updated Dino MSE for Image 3 = 0.21855226159095764
# Iteration 1 - Difference = -0.01361781358718872
#
# Iteration 1 - Original Dino MSE for Image 4 = 0.16918054223060608
# Iteration 1 - Updated Dino MSE for Image 4 = 0.15813253819942474
# Iteration 1 - Difference = -0.011048004031181335
#
# Iteration 1 - Original Dino MSE for Image 5 = 0.1919342428445816
# Iteration 1 - Updated Dino MSE for Image 5 = 0.17343859374523163
# Iteration 1 - Difference = -0.018495649099349976
#
# Iteration 1 - Original Dino MSE for Image 6 = 0.12380967289209366
# Iteration 1 - Updated Dino MSE for Image 6 = 0.12628595530986786
# Iteration 1 - Difference = 0.0024762824177742004
#
# Iteration 1 - Original Dino MSE for Image 7 = 0.15247498452663422
# Iteration 1 - Updated Dino MSE for Image 7 = 0.14283767342567444
# Iteration 1 - Difference = -0.009637311100959778
#
# Iteration 1 - Original Dino MSE for Image 8 = 0.19276215136051178
# Iteration 1 - Updated Dino MSE for Image 8 = 0.18321800231933594
# Iteration 1 - Difference = -0.009544149041175842
#
# Iteration 1 - Original Dino MSE for Image 9 = 0.2151387631893158
# Iteration 1 - Updated Dino MSE for Image 9 = 0.2040286362171173
# Iteration 1 - Difference = -0.011110126972198486
#
# Iteration 1 - Original Dino MSE for Image 10 = 0.1524471640586853
# Iteration 1 - Updated Dino MSE for Image 10 = 0.15790902078151703
# Iteration 1 - Difference = 0.005461856722831726
#
# Iteration 1 - Original Dino MSE for Image 11 = 0.2388329654932022
# Iteration 1 - Updated Dino MSE for Image 11 = 0.2270500361919403
# Iteration 1 - Difference = -0.011782929301261902
#
# Iteration 1 - Original Dino MSE for Image 12 = 0.19232597947120667
# Iteration 1 - Updated Dino MSE for Image 12 = 0.18063832819461823
# Iteration 1 - Difference = -0.01168765127658844
#
# Iteration 1 - Original Dino MSE for Image 13 = 0.23566646873950958
# Iteration 1 - Updated Dino MSE for Image 13 = 0.21244198083877563
# Iteration 1 - Difference = -0.023224487900733948
#
# Iteration 1 - Original Dino MSE for Image 14 = 0.21828904747962952
# Iteration 1 - Updated Dino MSE for Image 14 = 0.20054219663143158
# Iteration 1 - Difference = -0.017746850848197937
#
# Iteration 1 - Original Dino MSE for Image 15 = 0.21649333834648132
# Iteration 1 - Updated Dino MSE for Image 15 = 0.2043118178844452
# Iteration 1 - Difference = -0.012181520462036133
#
# Iteration 1 - Original Dino MSE for Image 16 = 0.2788110673427582
# Iteration 1 - Updated Dino MSE for Image 16 = 0.2602154016494751
# Iteration 1 - Difference = -0.01859566569328308
#
# Iteration 1 - Original Dino MSE for Image 17 = 0.2991960048675537
# Iteration 1 - Updated Dino MSE for Image 17 = 0.28607141971588135
# Iteration 1 - Difference = -0.013124585151672363
#
# Iteration 1 - Original Dino MSE for Image 18 = 0.2939864695072174
# Iteration 1 - Updated Dino MSE for Image 18 = 0.27444133162498474
# Iteration 1 - Difference = -0.019545137882232666
#
# Iteration 1 - Original Dino MSE for Image 19 = 0.2822563052177429
# Iteration 1 - Updated Dino MSE for Image 19 = 0.2723160982131958
# Iteration 1 - Difference = -0.00994020700454712
#
# Iteration 1 - Original Dino MSE for Image 20 = 0.20997768640518188
# Iteration 1 - Updated Dino MSE for Image 20 = 0.20410926640033722
# Iteration 1 - Difference = -0.0058684200048446655
#
# Iteration 1 - Original Dino MSE for Image 21 = 0.1793728619813919
# Iteration 1 - Updated Dino MSE for Image 21 = 0.176994189620018
# Iteration 1 - Difference = -0.0023786723613739014
#
# Iteration 1 - Original Dino MSE for Image 22 = 0.21577952802181244
# Iteration 1 - Updated Dino MSE for Image 22 = 0.20300979912281036
# Iteration 1 - Difference = -0.012769728899002075
#
# Iteration 1 - Original Dino MSE for Image 23 = 0.1802201122045517
# Iteration 1 - Updated Dino MSE for Image 23 = 0.17937134206295013
# Iteration 1 - Difference = -0.0008487701416015625
#
# Iteration 1 - Original Dino MSE for Image 24 = 0.16809576749801636
# Iteration 1 - Updated Dino MSE for Image 24 = 0.16250799596309662
# Iteration 1 - Difference = -0.005587771534919739
#
# Iteration 1 - Original Dino MSE for Image 25 = 0.1732526421546936
# Iteration 1 - Updated Dino MSE for Image 25 = 0.15869775414466858
# Iteration 1 - Difference = -0.014554888010025024
#
# Iteration 1 - Original Dino MSE for Image 26 = 0.2554466724395752
# Iteration 1 - Updated Dino MSE for Image 26 = 0.2318103313446045
# Iteration 1 - Difference = -0.023636341094970703
#
# Iteration 1 - Original Dino MSE for Image 27 = 0.23703376948833466
# Iteration 1 - Updated Dino MSE for Image 27 = 0.2277859002351761
# Iteration 1 - Difference = -0.00924786925315857
#
# Iteration 1 - Original Dino MSE for Image 28 = 0.2237587571144104
# Iteration 1 - Updated Dino MSE for Image 28 = 0.22149068117141724
# Iteration 1 - Difference = -0.002268075942993164
#
# Iteration 1 - Original Dino MSE for Image 29 = 0.18382135033607483
# Iteration 1 - Updated Dino MSE for Image 29 = 0.17371469736099243
# Iteration 1 - Difference = -0.010106652975082397
#
# Iteration 1 - Original Dino MSE for Image 30 = 0.2309509515762329
# Iteration 1 - Updated Dino MSE for Image 30 = 0.21142402291297913
# Iteration 1 - Difference = -0.019526928663253784
#
# Iteration 1 - Original Dino MSE for Image 31 = 0.17370520532131195
# Iteration 1 - Updated Dino MSE for Image 31 = 0.1559039205312729
# Iteration 1 - Difference = -0.017801284790039062
#
# Iteration 1 - Original Dino MSE for Image 32 = 0.21889425814151764
# Iteration 1 - Updated Dino MSE for Image 32 = 0.17546695470809937
# Iteration 1 - Difference = -0.043427303433418274
#
# Iteration 1 - Original Dino MSE for Image 33 = 0.46187323331832886
# Iteration 1 - Updated Dino MSE for Image 33 = 0.3469625413417816
# Iteration 1 - Difference = -0.11491069197654724
#
# Iteration 1 - Original Dino MSE for Image 34 = 0.38091546297073364
# Iteration 1 - Updated Dino MSE for Image 34 = 0.31864503026008606
# Iteration 1 - Difference = -0.06227043271064758
#
# Iteration 1 - Original Dino MSE for Image 35 = 0.2250550091266632
# Iteration 1 - Updated Dino MSE for Image 35 = 0.20567281544208527
# Iteration 1 - Difference = -0.019382193684577942
#
# Iteration 1 - Original Dino MSE for Image 36 = 0.21850505471229553
# Iteration 1 - Updated Dino MSE for Image 36 = 0.19968345761299133
# Iteration 1 - Difference = -0.0188215970993042
#
# Iteration 1 - Original Dino MSE for Image 37 = 0.23471471667289734
# Iteration 1 - Updated Dino MSE for Image 37 = 0.23054322600364685
# Iteration 1 - Difference = -0.004171490669250488
#
# Iteration 1 - Original Dino MSE for Image 38 = 0.2461712658405304
# Iteration 1 - Updated Dino MSE for Image 38 = 0.22321371734142303
# Iteration 1 - Difference = -0.02295754849910736
#
# Iteration 1 - Original Dino MSE for Image 39 = 0.25165921449661255
# Iteration 1 - Updated Dino MSE for Image 39 = 0.24213676154613495
# Iteration 1 - Difference = -0.0095224529504776
#
# Iteration 1 - Original Dino MSE for Image 40 = 0.23710371553897858
# Iteration 1 - Updated Dino MSE for Image 40 = 0.22439709305763245
# Iteration 1 - Difference = -0.01270662248134613
#
# Iteration 1 - Original Dino MSE for Image 41 = 0.20689231157302856
# Iteration 1 - Updated Dino MSE for Image 41 = 0.19880367815494537
# Iteration 1 - Difference = -0.008088633418083191
#
# Iteration 1 - Original Dino MSE for Image 42 = 0.23623701930046082
# Iteration 1 - Updated Dino MSE for Image 42 = 0.22323955595493317
# Iteration 1 - Difference = -0.012997463345527649
#
# Iteration 1 - Original Dino MSE for Image 43 = 0.31441691517829895
# Iteration 1 - Updated Dino MSE for Image 43 = 0.27653002738952637
# Iteration 1 - Difference = -0.03788688778877258
#
# Iteration 1 - Original Dino MSE for Image 44 = 0.286571204662323
# Iteration 1 - Updated Dino MSE for Image 44 = 0.28386053442955017
# Iteration 1 - Difference = -0.002710670232772827
#
# Iteration 1 - Original Dino MSE for Image 45 = 0.44337138533592224
# Iteration 1 - Updated Dino MSE for Image 45 = 0.4219166934490204
# Iteration 1 - Difference = -0.021454691886901855
#
# Iteration 1 - Original Dino MSE for Image 46 = 0.2658337950706482
# Iteration 1 - Updated Dino MSE for Image 46 = 0.26532694697380066
# Iteration 1 - Difference = -0.0005068480968475342
#
# Iteration 1 - Original Dino MSE for Image 47 = 0.3117736279964447
# Iteration 1 - Updated Dino MSE for Image 47 = 0.30972611904144287
# Iteration 1 - Difference = -0.002047508955001831
#
# Iteration 1 - Original Dino MSE for Image 48 = 0.26211023330688477
# Iteration 1 - Updated Dino MSE for Image 48 = 0.2423396110534668
# Iteration 1 - Difference = -0.01977062225341797
#
# Iteration 1 - Original Dino MSE for Image 49 = 0.2000478208065033
# Iteration 1 - Updated Dino MSE for Image 49 = 0.20048987865447998
# Iteration 1 - Difference = 0.00044205784797668457
#
# Iteration 1 - Original Dino MSE for Image 50 = 0.23981180787086487
# Iteration 1 - Updated Dino MSE for Image 50 = 0.22638671100139618
# Iteration 1 - Difference = -0.013425096869468689
#
# Iteration 1 - Original Dino MSE for Image 51 = 0.2845131754875183
# Iteration 1 - Updated Dino MSE for Image 51 = 0.2671697437763214
# Iteration 1 - Difference = -0.0173434317111969
#
# Iteration 1 - Original Dino MSE for Image 52 = 0.222128763794899
# Iteration 1 - Updated Dino MSE for Image 52 = 0.23783032596111298
# Iteration 1 - Difference = 0.01570156216621399
#
# Iteration 1 - Original Dino MSE for Image 53 = 0.214969202876091
# Iteration 1 - Updated Dino MSE for Image 53 = 0.21104586124420166
# Iteration 1 - Difference = -0.003923341631889343
#
# Iteration 1 - Original Dino MSE for Image 54 = 0.17861036956310272
# Iteration 1 - Updated Dino MSE for Image 54 = 0.16438168287277222
# Iteration 1 - Difference = -0.014228686690330505
#
# Iteration 1 - Original Dino MSE for Image 55 = 0.1671760082244873
# Iteration 1 - Updated Dino MSE for Image 55 = 0.15869678556919098
# Iteration 1 - Difference = -0.008479222655296326
#
# Iteration 1 - Original Dino MSE for Image 56 = 0.2929726839065552
# Iteration 1 - Updated Dino MSE for Image 56 = 0.2530486285686493
# Iteration 1 - Difference = -0.039924055337905884
#
# Iteration 1 - Original Dino MSE for Image 57 = 0.24876074492931366
# Iteration 1 - Updated Dino MSE for Image 57 = 0.2503398060798645
# Iteration 1 - Difference = 0.0015790611505508423
#
# Iteration 1 - Original Dino MSE for Image 58 = 0.29977306723594666
# Iteration 1 - Updated Dino MSE for Image 58 = 0.28432270884513855
# Iteration 1 - Difference = -0.015450358390808105
#
# Iteration 1 - Original Dino MSE for Image 59 = 0.21820387244224548
# Iteration 1 - Updated Dino MSE for Image 59 = 0.21893109381198883
# Iteration 1 - Difference = 0.0007272213697433472
#
# Iteration 1 - Original Dino MSE for Image 60 = 0.29151013493537903
# Iteration 1 - Updated Dino MSE for Image 60 = 0.2820545732975006
# Iteration 1 - Difference = -0.009455561637878418
#
# Iteration 1 - Original Dino MSE for Image 61 = 0.27752965688705444
# Iteration 1 - Updated Dino MSE for Image 61 = 0.27416539192199707
# Iteration 1 - Difference = -0.003364264965057373
#
# Iteration 1 - Original Dino MSE for Image 62 = 0.2895907461643219
# Iteration 1 - Updated Dino MSE for Image 62 = 0.27439022064208984
# Iteration 1 - Difference = -0.015200525522232056
#
# Iteration 1 - Original Dino MSE for Image 63 = 0.2052570879459381
# Iteration 1 - Updated Dino MSE for Image 63 = 0.21779556572437286
# Iteration 1 - Difference = 0.012538477778434753
#
# Iteration 1 - Original Dino MSE for Image 64 = 0.15977320075035095
# Iteration 1 - Updated Dino MSE for Image 64 = 0.162390798330307
# Iteration 1 - Difference = 0.0026175975799560547
#
# Iteration 1 - Original Dino MSE for Image 65 = 0.2917775809764862
# Iteration 1 - Updated Dino MSE for Image 65 = 0.30092760920524597
# Iteration 1 - Difference = 0.009150028228759766
#
# Iteration 1 - Original Dino MSE for Image 66 = 0.16730399429798126
# Iteration 1 - Updated Dino MSE for Image 66 = 0.19220411777496338
# Iteration 1 - Difference = 0.024900123476982117
#
# Iteration 1 - Original Dino MSE for Image 67 = 0.11794400215148926
# Iteration 1 - Updated Dino MSE for Image 67 = 0.11756902188062668
# Iteration 1 - Difference = -0.00037498027086257935
#
# Iteration 1 - Original Dino MSE for Image 68 = 0.1530061513185501
# Iteration 1 - Updated Dino MSE for Image 68 = 0.19918256998062134
# Iteration 1 - Difference = 0.04617641866207123
#
# Iteration 1 - Original Dino MSE for Image 69 = 0.2852895259857178
# Iteration 1 - Updated Dino MSE for Image 69 = 0.2610847055912018
# Iteration 1 - Difference = -0.02420482039451599
#
# Iteration 1 - Original Dino MSE for Image 70 = 0.08763149380683899
# Iteration 1 - Updated Dino MSE for Image 70 = 0.10750986635684967
# Iteration 1 - Difference = 0.01987837255001068
#
# Iteration 1 - Original Dino MSE for Image 71 = 0.16887402534484863
# Iteration 1 - Updated Dino MSE for Image 71 = 0.1478482037782669
# Iteration 1 - Difference = -0.021025821566581726
#
# Iteration 1 - Original Dino MSE for Image 72 = 0.11875037103891373
# Iteration 1 - Updated Dino MSE for Image 72 = 0.1232152134180069
# Iteration 1 - Difference = 0.00446484237909317
#
# Iteration 1 - Original Dino MSE for Image 73 = 0.18007215857505798
# Iteration 1 - Updated Dino MSE for Image 73 = 0.16671119630336761
# Iteration 1 - Difference = -0.013360962271690369
#
# Iteration 1 - Original Dino MSE for Image 74 = 0.11179962009191513
# Iteration 1 - Updated Dino MSE for Image 74 = 0.11366969347000122
# Iteration 1 - Difference = 0.00187007337808609
#
# Iteration 1 - Original Dino MSE for Image 75 = 0.20570288598537445
# Iteration 1 - Updated Dino MSE for Image 75 = 0.18183258175849915
# Iteration 1 - Difference = -0.023870304226875305
#
# Iteration 1 - Original Dino MSE for Image 76 = 0.19121937453746796
# Iteration 1 - Updated Dino MSE for Image 76 = 0.1906389743089676
# Iteration 1 - Difference = -0.0005804002285003662
#
# Iteration 1 - Original Dino MSE for Image 77 = 0.1626543253660202
# Iteration 1 - Updated Dino MSE for Image 77 = 0.16515736281871796
# Iteration 1 - Difference = 0.002503037452697754
#
# Iteration 1 - Original Dino MSE for Image 78 = 0.1116304099559784
# Iteration 1 - Updated Dino MSE for Image 78 = 0.11603681743144989
# Iteration 1 - Difference = 0.004406407475471497
#
# Iteration 1 - Original Dino MSE for Image 79 = 0.14166167378425598
# Iteration 1 - Updated Dino MSE for Image 79 = 0.13070282340049744
# Iteration 1 - Difference = -0.010958850383758545
#
# Iteration 1 - Original Dino MSE for Image 80 = 0.1318349987268448
# Iteration 1 - Updated Dino MSE for Image 80 = 0.13008089363574982
# Iteration 1 - Difference = -0.0017541050910949707
#
# Iteration 1 - Original Dino MSE for Image 81 = 0.1495172381401062
# Iteration 1 - Updated Dino MSE for Image 81 = 0.1424366682767868
# Iteration 1 - Difference = -0.007080569863319397
#
# Iteration 1 - Original Dino MSE for Image 82 = 0.1372205913066864
# Iteration 1 - Updated Dino MSE for Image 82 = 0.13469883799552917
# Iteration 1 - Difference = -0.0025217533111572266
#
# Iteration 1 - Original Dino MSE for Image 83 = 0.11035030335187912
# Iteration 1 - Updated Dino MSE for Image 83 = 0.11277128756046295
# Iteration 1 - Difference = 0.002420984208583832
#
# Iteration 1 - Original Dino MSE for Image 84 = 0.12822633981704712
# Iteration 1 - Updated Dino MSE for Image 84 = 0.1213555559515953
# Iteration 1 - Difference = -0.006870783865451813
#
# Iteration 1 - Original Dino MSE for Image 85 = 0.1157885491847992
# Iteration 1 - Updated Dino MSE for Image 85 = 0.11158230900764465
# Iteration 1 - Difference = -0.004206240177154541
#
# Iteration 1 - Original Dino MSE for Image 86 = 0.1069382056593895
# Iteration 1 - Updated Dino MSE for Image 86 = 0.10021267086267471
# Iteration 1 - Difference = -0.006725534796714783
#
# Iteration 1 - Original Dino MSE for Image 87 = 0.11483161896467209
# Iteration 1 - Updated Dino MSE for Image 87 = 0.10899858176708221
# Iteration 1 - Difference = -0.005833037197589874
#
# Iteration 1 - Original Dino MSE for Image 88 = 0.09089407324790955
# Iteration 1 - Updated Dino MSE for Image 88 = 0.09357639402151108
# Iteration 1 - Difference = 0.002682320773601532
#
# Iteration 1 - Original Dino MSE for Image 89 = 0.11098245531320572
# Iteration 1 - Updated Dino MSE for Image 89 = 0.1010480672121048
# Iteration 1 - Difference = -0.009934388101100922
#
# Iteration 1 - Original Dino MSE for Image 90 = 0.2806840240955353
# Iteration 1 - Updated Dino MSE for Image 90 = 0.24195162951946259
# Iteration 1 - Difference = -0.03873239457607269
#
# Iteration 1 - Original Dino MSE for Image 91 = 0.2136581689119339
# Iteration 1 - Updated Dino MSE for Image 91 = 0.22224849462509155
# Iteration 1 - Difference = 0.008590325713157654
#
# Iteration 1 - Original Dino MSE for Image 92 = 0.1589306741952896
# Iteration 1 - Updated Dino MSE for Image 92 = 0.16146738827228546
# Iteration 1 - Difference = 0.0025367140769958496
#
# Iteration 1 - Original Dino MSE for Image 93 = 0.1770540475845337
# Iteration 1 - Updated Dino MSE for Image 93 = 0.17236818373203278
# Iteration 1 - Difference = -0.0046858638525009155
#
# Iteration 1 - Original Dino MSE for Image 94 = 0.1413079798221588
# Iteration 1 - Updated Dino MSE for Image 94 = 0.1310487985610962
# Iteration 1 - Difference = -0.010259181261062622
#
# Iteration 1 - Original Dino MSE for Image 95 = 0.17052863538265228
# Iteration 1 - Updated Dino MSE for Image 95 = 0.15760429203510284
# Iteration 1 - Difference = -0.012924343347549438
#
# Iteration 1 - Original Dino MSE for Image 96 = 0.18533554673194885
# Iteration 1 - Updated Dino MSE for Image 96 = 0.1664726436138153
# Iteration 1 - Difference = -0.018862903118133545
#
# Iteration 1 - Original Dino MSE for Image 97 = 0.20922590792179108
# Iteration 1 - Updated Dino MSE for Image 97 = 0.18318645656108856
# Iteration 1 - Difference = -0.026039451360702515
#
# Iteration 1 - Original Dino MSE for Image 98 = 0.2591285705566406
# Iteration 1 - Updated Dino MSE for Image 98 = 0.22887122631072998
# Iteration 1 - Difference = -0.030257344245910645
#
# Iteration 1 - Original Dino MSE for Image 99 = 0.23973414301872253
# Iteration 1 - Updated Dino MSE for Image 99 = 0.20799489319324493
# Iteration 1 - Difference = -0.0317392498254776
#
# Iteration 1 - Original Dino MSE for Image 100 = 0.17926110327243805
# Iteration 1 - Updated Dino MSE for Image 100 = 0.16346219182014465
# Iteration 1 - Difference = -0.015798911452293396
#
# Iteration 1 - Original Dino MSE for Image 101 = 0.14621230959892273
# Iteration 1 - Updated Dino MSE for Image 101 = 0.1444370597600937
# Iteration 1 - Difference = -0.0017752498388290405
#
# Iteration 1 - Original Dino MSE for Image 102 = 0.1065438985824585
# Iteration 1 - Updated Dino MSE for Image 102 = 0.11198250949382782
# Iteration 1 - Difference = 0.005438610911369324
#
# Iteration 1 - Original Dino MSE for Image 103 = 0.10774075239896774
#
# Iteration 1 - Original Dino MSE for Image 104 = 0.09281272441148758
# Iteration 1 - Updated Dino MSE for Image 104 = 0.08331556618213654
# Iteration 1 - Difference = -0.009497158229351044
#
# Iteration 1 - Original Dino MSE for Image 105 = 0.06975442916154861
# Iteration 1 - Updated Dino MSE for Image 105 = 0.08004597574472427
# Iteration 1 - Difference = 0.01029154658317566
#
# Iteration 1 - Original Dino MSE for Image 106 = 0.06481579691171646
# Iteration 1 - Updated Dino MSE for Image 106 = 0.07108426839113235
# Iteration 1 - Difference = 0.0062684714794158936
#
# Iteration 1 - Original Dino MSE for Image 107 = 0.04986676573753357
# Iteration 1 - Updated Dino MSE for Image 107 = 0.050784021615982056
# Iteration 1 - Difference = 0.0009172558784484863
#
# Iteration 1 - Original Dino MSE for Image 108 = 0.047929778695106506
# Iteration 1 - Updated Dino MSE for Image 108 = 0.05144410952925682
# Iteration 1 - Difference = 0.0035143308341503143
#
# Iteration 1 - Original Dino MSE for Image 109 = 0.05050256475806236
# Iteration 1 - Updated Dino MSE for Image 109 = 0.05213655158877373
# Iteration 1 - Difference = 0.0016339868307113647
#
# Iteration 1 - Original Dino MSE for Image 110 = 0.07430195808410645
# Iteration 1 - Updated Dino MSE for Image 110 = 0.07315614819526672
# Iteration 1 - Difference = -0.0011458098888397217
#
# Iteration 1 - Original Dino MSE for Image 111 = 0.08451830595731735
# Iteration 1 - Updated Dino MSE for Image 111 = 0.08885854482650757
# Iteration 1 - Difference = 0.004340238869190216
#
# Iteration 1 - Original Dino MSE for Image 112 = 0.12199191749095917
# Iteration 1 - Updated Dino MSE for Image 112 = 0.12573130428791046
# Iteration 1 - Difference = 0.003739386796951294
#
# Iteration 1 - Original Dino MSE for Image 113 = 0.11876928061246872
# Iteration 1 - Updated Dino MSE for Image 113 = 0.13051143288612366
# Iteration 1 - Difference = 0.011742152273654938
#
# Iteration 1 - Original Dino MSE for Image 114 = 0.20700399577617645
# Iteration 1 - Updated Dino MSE for Image 114 = 0.20011144876480103
# Iteration 1 - Difference = -0.006892547011375427
#
# Iteration 1 - Original Dino MSE for Image 115 = 0.15067467093467712
# Iteration 1 - Updated Dino MSE for Image 115 = 0.1504526436328888
# Iteration 1 - Difference = -0.00022202730178833008
#
# Iteration 1 - Original Dino MSE for Image 116 = 0.13522978127002716
# Iteration 1 - Updated Dino MSE for Image 116 = 0.13383780419826508
# Iteration 1 - Difference = -0.001391977071762085
#
# Iteration 1 - Original Dino MSE for Image 117 = 0.09423166513442993
# Iteration 1 - Updated Dino MSE for Image 117 = 0.09574044495820999
# Iteration 1 - Difference = 0.0015087798237800598
#
# Iteration 1 - Original Dino MSE for Image 118 = 0.11143999546766281
# Iteration 1 - Updated Dino MSE for Image 118 = 0.10433676838874817
# Iteration 1 - Difference = -0.007103227078914642
#
# Iteration 1 - Original Dino MSE for Image 119 = 0.10771160572767258
#
# Iteration 1 - Original Dino MSE for Image 120 = 0.08437409996986389
# Iteration 1 - Updated Dino MSE for Image 120 = 0.09980227798223495
# Iteration 1 - Difference = 0.015428178012371063
#
# Iteration 1 - Original Dino MSE for Image 121 = 0.2076818346977234
# Iteration 1 - Updated Dino MSE for Image 121 = 0.18100719153881073
# Iteration 1 - Difference = -0.02667464315891266
#
# Iteration 1 - Original Dino MSE for Image 122 = 0.12535500526428223
# Iteration 1 - Updated Dino MSE for Image 122 = 0.12960772216320038
# Iteration 1 - Difference = 0.004252716898918152
#
# Iteration 1 - Original Dino MSE for Image 123 = 0.13278841972351074
# Iteration 1 - Updated Dino MSE for Image 123 = 0.13466432690620422
# Iteration 1 - Difference = 0.0018759071826934814
#
# Iteration 1 - Original Dino MSE for Image 124 = 0.12246620655059814
# Iteration 1 - Updated Dino MSE for Image 124 = 0.11523042619228363
# Iteration 1 - Difference = -0.007235780358314514
#
# Iteration 1 - Original Dino MSE for Image 125 = 0.1660168170928955
# Iteration 1 - Updated Dino MSE for Image 125 = 0.155057892203331
# Iteration 1 - Difference = -0.010958924889564514
#
# Iteration 1 - Original Dino MSE for Image 126 = 0.14669793844223022
# Iteration 1 - Updated Dino MSE for Image 126 = 0.14823795855045319
# Iteration 1 - Difference = 0.0015400201082229614
#
# Iteration 1 - Original Dino MSE for Image 127 = 0.19247817993164062
# Iteration 1 - Updated Dino MSE for Image 127 = 0.1883072406053543
# Iteration 1 - Difference = -0.004170939326286316
#
# Iteration 1 - Original Dino MSE for Image 128 = 0.21111491322517395
# Iteration 1 - Updated Dino MSE for Image 128 = 0.22444947063922882
# Iteration 1 - Difference = 0.01333455741405487
#
# Iteration 1 - Original Dino MSE for Image 129 = 0.15272866189479828
# Iteration 1 - Updated Dino MSE for Image 129 = 0.14453592896461487
# Iteration 1 - Difference = -0.00819273293018341
#
# Iteration 1 - Original Dino MSE for Image 130 = 0.19246485829353333
# Iteration 1 - Updated Dino MSE for Image 130 = 0.1913546323776245
# Iteration 1 - Difference = -0.0011102259159088135
#
# Iteration 1 - Original Dino MSE for Image 131 = 0.11564312130212784
# Iteration 1 - Updated Dino MSE for Image 131 = 0.11471869796514511
# Iteration 1 - Difference = -0.000924423336982727
#
# Iteration 1 - Original Dino MSE for Image 132 = 0.117696613073349
# Iteration 1 - Updated Dino MSE for Image 132 = 0.11483780294656754
# Iteration 1 - Difference = -0.0028588101267814636
#
# Iteration 1 - Original Dino MSE for Image 133 = 0.12915390729904175
# Iteration 1 - Updated Dino MSE for Image 133 = 0.13020287454128265
# Iteration 1 - Difference = 0.0010489672422409058
#
# Iteration 1 - Original Dino MSE for Image 134 = 0.3247731626033783
# Iteration 1 - Updated Dino MSE for Image 134 = 0.30695265531539917
# Iteration 1 - Difference = -0.017820507287979126
#
# Iteration 1 - Original Dino MSE for Image 135 = 0.2889223098754883
# Iteration 1 - Updated Dino MSE for Image 135 = 0.25467491149902344
# Iteration 1 - Difference = -0.034247398376464844
#
# Iteration 1 - Original Dino MSE for Image 136 = 0.2855879068374634
# Iteration 1 - Updated Dino MSE for Image 136 = 0.23492158949375153
# Iteration 1 - Difference = -0.05066631734371185
#
# Iteration 1 - Original Dino MSE for Image 137 = 0.8124271035194397
# Iteration 1 - Updated Dino MSE for Image 137 = 0.779415488243103
# Iteration 1 - Difference = -0.03301161527633667
#
# Iteration 1 - Original Dino MSE for Image 138 = 0.7601954340934753
# Iteration 1 - Updated Dino MSE for Image 138 = 0.6543341875076294
# Iteration 1 - Difference = -0.10586124658584595
#
# Iteration 1 - Original Dino MSE for Image 139 = 0.6562538743019104
# Iteration 1 - Updated Dino MSE for Image 139 = 0.6272312998771667
# Iteration 1 - Difference = -0.029022574424743652
#
# Iteration 1 - Original Dino MSE for Image 140 = 0.652202308177948
# Iteration 1 - Updated Dino MSE for Image 140 = 0.5733749866485596
# Iteration 1 - Difference = -0.07882732152938843
#
# Iteration 1 - Original Dino MSE for Image 141 = 0.6756793856620789
# Iteration 1 - Updated Dino MSE for Image 141 = 0.6048222184181213
# Iteration 1 - Difference = -0.07085716724395752
#
# Iteration 1 - Original Dino MSE for Image 142 = 0.242466002702713
# Iteration 1 - Updated Dino MSE for Image 142 = 0.22849778831005096
# Iteration 1 - Difference = -0.013968214392662048
#
# Iteration 1 - Original Dino MSE for Image 143 = 0.38986071944236755
# Iteration 1 - Updated Dino MSE for Image 143 = 0.3247717320919037
# Iteration 1 - Difference = -0.06508898735046387
#
# Iteration 1 - Original Dino MSE for Image 144 = 0.2977522313594818
# Iteration 1 - Updated Dino MSE for Image 144 = 0.2731981575489044
# Iteration 1 - Difference = -0.024554073810577393
#
# Iteration 1 - Original Dino MSE for Image 145 = 0.3501909077167511
# Iteration 1 - Updated Dino MSE for Image 145 = 0.2983165383338928
# Iteration 1 - Difference = -0.051874369382858276
#
# Iteration 1 - Original Dino MSE for Image 146 = 0.3875596225261688
# Iteration 1 - Updated Dino MSE for Image 146 = 0.34932374954223633
# Iteration 1 - Difference = -0.038235872983932495
#
# Iteration 1 - Original Dino MSE for Image 147 = 0.25724104046821594
# Iteration 1 - Updated Dino MSE for Image 147 = 0.24601824581623077
# Iteration 1 - Difference = -0.011222794651985168
#
# Iteration 1 - Original Dino MSE for Image 148 = 0.18382957577705383
# Iteration 1 - Updated Dino MSE for Image 148 = 0.19434840977191925
# Iteration 1 - Difference = 0.010518833994865417
#
# Iteration 1 - Original Dino MSE for Image 149 = 0.18920500576496124
# Iteration 1 - Updated Dino MSE for Image 149 = 0.1857636570930481
# Iteration 1 - Difference = -0.003441348671913147
#
# Iteration 1 - Original Dino MSE for Image 150 = 0.3031584322452545
# Iteration 1 - Updated Dino MSE for Image 150 = 0.28906795382499695
# Iteration 1 - Difference = -0.014090478420257568
#
# Iteration 1 - Original Dino MSE for Image 151 = 0.23087187111377716
# Iteration 1 - Updated Dino MSE for Image 151 = 0.22955450415611267
# Iteration 1 - Difference = -0.0013173669576644897
#
# Iteration 1 - Original Dino MSE for Image 152 = 0.19797676801681519
# Iteration 1 - Updated Dino MSE for Image 152 = 0.18321987986564636
# Iteration 1 - Difference = -0.014756888151168823
#
# Iteration 1 - Original Dino MSE for Image 153 = 0.19155363738536835
# Iteration 1 - Updated Dino MSE for Image 153 = 0.1856178641319275
# Iteration 1 - Difference = -0.005935773253440857
#
# Iteration 1 - Original Dino MSE for Image 154 = 0.14361590147018433
# Iteration 1 - Updated Dino MSE for Image 154 = 0.1466955542564392
# Iteration 1 - Difference = 0.003079652786254883
#
# Iteration 1 - Original Dino MSE for Image 155 = 0.102487713098526
# Iteration 1 - Updated Dino MSE for Image 155 = 0.1025233119726181
# Iteration 1 - Difference = 3.559887409210205e-05
#
# Iteration 1 - Original Dino MSE for Image 156 = 0.1443644016981125
# Iteration 1 - Updated Dino MSE for Image 156 = 0.1399158388376236
# Iteration 1 - Difference = -0.004448562860488892
#
# Iteration 1 - Original Dino MSE for Image 157 = 0.08446017652750015
# Iteration 1 - Updated Dino MSE for Image 157 = 0.08298228681087494
# Iteration 1 - Difference = -0.0014778897166252136
#
# Iteration 1 - Original Dino MSE for Image 158 = 0.10885170102119446
# Iteration 1 - Updated Dino MSE for Image 158 = 0.10689222067594528
# Iteration 1 - Difference = -0.001959480345249176
#
# Iteration 1 - Original Dino MSE for Image 159 = 0.10834140330553055
# Iteration 1 - Updated Dino MSE for Image 159 = 0.1050804927945137
# Iteration 1 - Difference = -0.0032609105110168457
#
# Iteration 1 - Original Dino MSE for Image 160 = 0.10560132563114166
# Iteration 1 - Updated Dino MSE for Image 160 = 0.10372215509414673
# Iteration 1 - Difference = -0.001879170536994934
#
# Iteration 1 - Original Dino MSE for Image 161 = 0.13844461739063263
# Iteration 1 - Updated Dino MSE for Image 161 = 0.13590486347675323
# Iteration 1 - Difference = -0.0025397539138793945
#
# Iteration 1 - Original Dino MSE for Image 162 = 0.09504706412553787
# Iteration 1 - Updated Dino MSE for Image 162 = 0.09669220447540283
# Iteration 1 - Difference = 0.0016451403498649597
#
# Iteration 1 - Original Dino MSE for Image 163 = 0.11019369214773178
# Iteration 1 - Updated Dino MSE for Image 163 = 0.10552027821540833
# Iteration 1 - Difference = -0.004673413932323456
#
# Iteration 1 - Original Dino MSE for Image 164 = 0.11348199099302292
# Iteration 1 - Updated Dino MSE for Image 164 = 0.11156027764081955
# Iteration 1 - Difference = -0.0019217133522033691
#
# Iteration 1 - Original Dino MSE for Image 165 = 0.11155905574560165
# Iteration 1 - Updated Dino MSE for Image 165 = 0.10821695625782013
# Iteration 1 - Difference = -0.0033420994877815247
#
# Iteration 1 - Original Dino MSE for Image 166 = 0.11306741833686829
# Iteration 1 - Updated Dino MSE for Image 166 = 0.11285391449928284
# Iteration 1 - Difference = -0.00021350383758544922
#
# Iteration 1 - Original Dino MSE for Image 167 = 0.15218746662139893
# Iteration 1 - Updated Dino MSE for Image 167 = 0.14331884682178497
# Iteration 1 - Difference = -0.008868619799613953
#
# Iteration 1 - Original Dino MSE for Image 168 = 0.14118468761444092
# Iteration 1 - Updated Dino MSE for Image 168 = 0.13690145313739777
# Iteration 1 - Difference = -0.004283234477043152
#
# Iteration 1 - Original Dino MSE for Image 169 = 0.13797958195209503
# Iteration 1 - Updated Dino MSE for Image 169 = 0.13220694661140442
# Iteration 1 - Difference = -0.005772635340690613
#
# Iteration 1 - Original Dino MSE for Image 170 = 0.1917581856250763
# Iteration 1 - Updated Dino MSE for Image 170 = 0.18097881972789764
# Iteration 1 - Difference = -0.01077936589717865
#
# Iteration 1 - Original Dino MSE for Image 171 = 0.16531561315059662
# Iteration 1 - Updated Dino MSE for Image 171 = 0.16688711941242218
# Iteration 1 - Difference = 0.0015715062618255615
#
# Iteration 1 - Original Dino MSE for Image 172 = 0.08849620819091797
# Iteration 1 - Updated Dino MSE for Image 172 = 0.09489154815673828
# Iteration 1 - Difference = 0.0063953399658203125
#
# Iteration 1 - Original Dino MSE for Image 173 = 0.14509227871894836
# Iteration 1 - Updated Dino MSE for Image 173 = 0.13006499409675598
# Iteration 1 - Difference = -0.015027284622192383
#
# Iteration 1 - Original Dino MSE for Image 174 = 0.12337591499090195
# Iteration 1 - Updated Dino MSE for Image 174 = 0.12064576894044876
# Iteration 1 - Difference = -0.002730146050453186
#
# Iteration 1 - Original Dino MSE for Image 175 = 0.14564937353134155
# Iteration 1 - Updated Dino MSE for Image 175 = 0.13093936443328857
# Iteration 1 - Difference = -0.014710009098052979
#
# Iteration 1 - Original Dino MSE for Image 176 = 0.25784075260162354
# Iteration 1 - Updated Dino MSE for Image 176 = 0.22953365743160248
# Iteration 1 - Difference = -0.028307095170021057
#
# Iteration 1 - Original Dino MSE for Image 177 = 0.17020927369594574
# Iteration 1 - Updated Dino MSE for Image 177 = 0.17393752932548523
# Iteration 1 - Difference = 0.0037282556295394897
#
# Iteration 1 - Original Dino MSE for Image 178 = 0.21767127513885498
# Iteration 1 - Updated Dino MSE for Image 178 = 0.1910100132226944
# Iteration 1 - Difference = -0.026661261916160583
#
# Iteration 1 - Original Dino MSE for Image 179 = 0.24346905946731567
# Iteration 1 - Updated Dino MSE for Image 179 = 0.23614482581615448
# Iteration 1 - Difference = -0.007324233651161194
#
# Iteration 1 - Original Dino MSE for Image 180 = 0.13883589208126068
# Iteration 1 - Updated Dino MSE for Image 180 = 0.14898239076137543
# Iteration 1 - Difference = 0.010146498680114746
#
# Iteration 1 - Original Dino MSE for Image 181 = 0.14172759652137756
# Iteration 1 - Updated Dino MSE for Image 181 = 0.1391829550266266
# Iteration 1 - Difference = -0.0025446414947509766
#
# Iteration 1 - Original Dino MSE for Image 182 = 0.13265861570835114
# Iteration 1 - Updated Dino MSE for Image 182 = 0.1319880485534668
# Iteration 1 - Difference = -0.0006705671548843384
#
# Iteration 1 - Original Dino MSE for Image 183 = 0.19038446247577667
# Iteration 1 - Updated Dino MSE for Image 183 = 0.18043045699596405
# Iteration 1 - Difference = -0.009954005479812622
#
# Iteration 1 - Original Dino MSE for Image 184 = 0.1320466250181198
# Iteration 1 - Updated Dino MSE for Image 184 = 0.134129598736763
# Iteration 1 - Difference = 0.0020829737186431885
#
# Iteration 1 - Original Dino MSE for Image 185 = 0.14023199677467346
# Iteration 1 - Updated Dino MSE for Image 185 = 0.13756127655506134
# Iteration 1 - Difference = -0.0026707202196121216
#
# Iteration 1 - Original Dino MSE for Image 186 = 0.15982909500598907
# Iteration 1 - Updated Dino MSE for Image 186 = 0.15945973992347717
# Iteration 1 - Difference = -0.00036935508251190186
#
# Iteration 1 - Original Dino MSE for Image 187 = 0.13159631192684174
# Iteration 1 - Updated Dino MSE for Image 187 = 0.13172684609889984
# Iteration 1 - Difference = 0.00013053417205810547
#
# Iteration 1 - Original Dino MSE for Image 188 = 0.1271219700574875
# Iteration 1 - Updated Dino MSE for Image 188 = 0.12760774791240692
# Iteration 1 - Difference = 0.0004857778549194336
#
# Iteration 1 - Original Dino MSE for Image 189 = 0.07879163324832916
# Iteration 1 - Updated Dino MSE for Image 189 = 0.07794122397899628
# Iteration 1 - Difference = -0.0008504092693328857
#
# Iteration 1 - Original Dino MSE for Image 190 = 0.07901033014059067
# Iteration 1 - Updated Dino MSE for Image 190 = 0.08090730011463165
# Iteration 1 - Difference = 0.001896969974040985
#
# Iteration 1 - Original Dino MSE for Image 191 = 0.14081914722919464
# Iteration 1 - Updated Dino MSE for Image 191 = 0.12483087182044983
# Iteration 1 - Difference = -0.015988275408744812
#
# Iteration 1 - Original Dino MSE for Image 192 = 0.15144087374210358
# Iteration 1 - Updated Dino MSE for Image 192 = 0.15212760865688324
# Iteration 1 - Difference = 0.0006867349147796631
#
# Iteration 1 - Original Dino MSE for Image 193 = 0.23929420113563538
# Iteration 1 - Updated Dino MSE for Image 193 = 0.2147948294878006
# Iteration 1 - Difference = -0.024499371647834778
#
# Iteration 1 - Original Dino MSE for Image 194 = 0.12305898219347
# Iteration 1 - Updated Dino MSE for Image 194 = 0.1328202784061432
# Iteration 1 - Difference = 0.009761296212673187
#
# Iteration 1 - Original Dino MSE for Image 195 = 0.2875112295150757
# Iteration 1 - Updated Dino MSE for Image 195 = 0.2646610140800476
# Iteration 1 - Difference = -0.022850215435028076
#
# Iteration 1 - Original Dino MSE for Image 196 = 0.1998572051525116
# Iteration 1 - Updated Dino MSE for Image 196 = 0.21641482412815094
# Iteration 1 - Difference = 0.016557618975639343
#
# Iteration 1 - Original Dino MSE for Image 197 = 0.15094521641731262
# Iteration 1 - Updated Dino MSE for Image 197 = 0.15298032760620117
# Iteration 1 - Difference = 0.00203511118888855
#
# Iteration 1 - Original Dino MSE for Image 198 = 0.12675724923610687
# Iteration 1 - Updated Dino MSE for Image 198 = 0.12099750339984894
# Iteration 1 - Difference = -0.005759745836257935
#
# Iteration 1 - Original Dino MSE for Image 199 = 0.19046443700790405
# Iteration 1 - Updated Dino MSE for Image 199 = 0.18779249489307404
# Iteration 1 - Difference = -0.002671942114830017
#
# Iteration 1 - Original Dino MSE for Image 200 = 0.22360128164291382
# Iteration 1 - Updated Dino MSE for Image 200 = 0.20730926096439362
# Iteration 1 - Difference = -0.016292020678520203
#
# Iteration 1 - Original Dino MSE for Image 201 = 0.23920570313930511
# Iteration 1 - Updated Dino MSE for Image 201 = 0.2458178997039795
# Iteration 1 - Difference = 0.0066121965646743774
#
# Iteration 1 - Original Dino MSE for Image 202 = 0.17063117027282715
# Iteration 1 - Updated Dino MSE for Image 202 = 0.17617033421993256
# Iteration 1 - Difference = 0.005539163947105408
#
# Iteration 1 - Original Dino MSE for Image 203 = 0.18090122938156128
# Iteration 1 - Updated Dino MSE for Image 203 = 0.18208064138889313
# Iteration 1 - Difference = 0.0011794120073318481
#
# Iteration 1 - Original Dino MSE for Image 204 = 0.154914990067482
# Iteration 1 - Updated Dino MSE for Image 204 = 0.14208544790744781
# Iteration 1 - Difference = -0.01282954216003418
#
# Iteration 1 - Original Dino MSE for Image 205 = 0.1952926367521286
# Iteration 1 - Updated Dino MSE for Image 205 = 0.18245510756969452
# Iteration 1 - Difference = -0.012837529182434082
#
# Iteration 1 - Original Dino MSE for Image 206 = 0.1634952872991562
# Iteration 1 - Updated Dino MSE for Image 206 = 0.1735912561416626
# Iteration 1 - Difference = 0.010095968842506409
#
# Iteration 1 - Original Dino MSE for Image 207 = 0.12500855326652527
# Iteration 1 - Updated Dino MSE for Image 207 = 0.1334238052368164
# Iteration 1 - Difference = 0.008415251970291138
#
# Iteration 1 - Original Dino MSE for Image 208 = 0.11167014390230179
# Iteration 1 - Updated Dino MSE for Image 208 = 0.10699760913848877
# Iteration 1 - Difference = -0.004672534763813019
#
# Iteration 1 - Original Dino MSE for Image 209 = 0.13343410193920135
# Iteration 1 - Updated Dino MSE for Image 209 = 0.130978524684906
# Iteration 1 - Difference = -0.002455577254295349
#
# Iteration 1 - Original Dino MSE for Image 210 = 0.09471838176250458
# Iteration 1 - Updated Dino MSE for Image 210 = 0.09603806585073471
# Iteration 1 - Difference = 0.001319684088230133
#
# Iteration 1 - Original Dino MSE for Image 211 = 0.14251407980918884
# Iteration 1 - Updated Dino MSE for Image 211 = 0.13735651969909668
# Iteration 1 - Difference = -0.005157560110092163
#
# Iteration 1 - Original Dino MSE for Image 212 = 0.14049208164215088
# Iteration 1 - Updated Dino MSE for Image 212 = 0.14447171986103058
# Iteration 1 - Difference = 0.0039796382188797
#
# Iteration 1 - Original Dino MSE for Image 213 = 0.1418532133102417
# Iteration 1 - Updated Dino MSE for Image 213 = 0.1363714188337326
# Iteration 1 - Difference = -0.005481794476509094
#
# Iteration 1 - Original Dino MSE for Image 214 = 0.09348075091838837
# Iteration 1 - Updated Dino MSE for Image 214 = 0.08877253532409668
# Iteration 1 - Difference = -0.004708215594291687
#
# Iteration 1 - Original Dino MSE for Image 215 = 0.13700443506240845
# Iteration 1 - Updated Dino MSE for Image 215 = 0.1330917626619339
# Iteration 1 - Difference = -0.003912672400474548
#
# Iteration 1 - Original Dino MSE for Image 216 = 0.09411496669054031
# Iteration 1 - Updated Dino MSE for Image 216 = 0.09566625207662582
# Iteration 1 - Difference = 0.0015512853860855103
#
# Iteration 1 - Original Dino MSE for Image 217 = 0.1290675550699234
# Iteration 1 - Updated Dino MSE for Image 217 = 0.13036192953586578
# Iteration 1 - Difference = 0.0012943744659423828
#
# Iteration 1 - Original Dino MSE for Image 218 = 0.15505041182041168
# Iteration 1 - Updated Dino MSE for Image 218 = 0.1583673506975174
# Iteration 1 - Difference = 0.003316938877105713
#
# Iteration 1 - Original Dino MSE for Image 219 = 0.11676632612943649
# Iteration 1 - Updated Dino MSE for Image 219 = 0.11860660463571548
# Iteration 1 - Difference = 0.0018402785062789917
#
# Iteration 1 - Original Dino MSE for Image 220 = 0.1044408529996872
# Iteration 1 - Updated Dino MSE for Image 220 = 0.10559418052434921
# Iteration 1 - Difference = 0.0011533275246620178
#
# Iteration 1 - Original Dino MSE for Image 221 = 0.07874190807342529
# Iteration 1 - Updated Dino MSE for Image 221 = 0.07777996361255646
# Iteration 1 - Difference = -0.0009619444608688354
#
# Iteration 1 - Original Dino MSE for Image 222 = 0.06904415786266327
# Iteration 1 - Updated Dino MSE for Image 222 = 0.06959990411996841
# Iteration 1 - Difference = 0.0005557462573051453
#
# Iteration 1 - Original Dino MSE for Image 223 = 0.11391329020261765
# Iteration 1 - Updated Dino MSE for Image 223 = 0.10877098143100739
# Iteration 1 - Difference = -0.00514230877161026
#
# Iteration 1 - Original Dino MSE for Image 224 = 0.1086321696639061
# Iteration 1 - Updated Dino MSE for Image 224 = 0.11182403564453125
# Iteration 1 - Difference = 0.0031918659806251526
#
# Iteration 1 - Original Dino MSE for Image 225 = 0.11553148180246353
# Iteration 1 - Updated Dino MSE for Image 225 = 0.11701910942792892
# Iteration 1 - Difference = 0.001487627625465393
#
# Iteration 1 - Original Dino MSE for Image 226 = 0.09225498139858246
# Iteration 1 - Updated Dino MSE for Image 226 = 0.0971170961856842
# Iteration 1 - Difference = 0.004862114787101746
#
# Iteration 1 - Original Dino MSE for Image 227 = 0.08013153821229935
# Iteration 1 - Updated Dino MSE for Image 227 = 0.07702966779470444
# Iteration 1 - Difference = -0.0031018704175949097
#
# Iteration 1 - Original Dino MSE for Image 228 = 0.11195863038301468
# Iteration 1 - Updated Dino MSE for Image 228 = 0.11176697164773941
# Iteration 1 - Difference = -0.00019165873527526855
#
# Iteration 1 - Original Dino MSE for Image 229 = 0.09325537830591202
# Iteration 1 - Updated Dino MSE for Image 229 = 0.09603657573461533
# Iteration 1 - Difference = 0.002781197428703308
#
# Iteration 1 - Original Dino MSE for Image 230 = 0.11607268452644348
# Iteration 1 - Updated Dino MSE for Image 230 = 0.1132330670952797
# Iteration 1 - Difference = -0.002839617431163788
#
# Iteration 1 - Original Dino MSE for Image 231 = 0.07878141105175018
# Iteration 1 - Updated Dino MSE for Image 231 = 0.08079610764980316
# Iteration 1 - Difference = 0.0020146965980529785
#
# Iteration 1 - Original Dino MSE for Image 232 = 0.05607675388455391
# Iteration 1 - Updated Dino MSE for Image 232 = 0.05859952047467232
# Iteration 1 - Difference = 0.002522766590118408
#
# Iteration 1 - Original Dino MSE for Image 233 = 0.058783598244190216
# Iteration 1 - Updated Dino MSE for Image 233 = 0.05675796419382095
# Iteration 1 - Difference = -0.0020256340503692627
#
# Iteration 1 - Original Dino MSE for Image 234 = 0.055148202925920486
# Iteration 1 - Updated Dino MSE for Image 234 = 0.05337637662887573
# Iteration 1 - Difference = -0.001771826297044754
#
# Iteration 1 - Original Dino MSE for Image 235 = 0.06777624785900116
# Iteration 1 - Updated Dino MSE for Image 235 = 0.06716100126504898
# Iteration 1 - Difference = -0.000615246593952179
#
# Iteration 1 - Original Dino MSE for Image 236 = 0.1208825409412384
# Iteration 1 - Updated Dino MSE for Image 236 = 0.12341120839118958
# Iteration 1 - Difference = 0.002528667449951172
#
# Iteration 1 - Original Dino MSE for Image 237 = 0.1343642920255661
# Iteration 1 - Updated Dino MSE for Image 237 = 0.137509286403656
# Iteration 1 - Difference = 0.003144994378089905
#
# Iteration 1 - Original Dino MSE for Image 238 = 0.06350774317979813
# Iteration 1 - Updated Dino MSE for Image 238 = 0.06743128597736359
# Iteration 1 - Difference = 0.00392354279756546
#
# Iteration 1 - Original Dino MSE for Image 239 = 0.048818737268447876
# Iteration 1 - Updated Dino MSE for Image 239 = 0.044682588428258896
# Iteration 1 - Difference = -0.00413614884018898
#
# Iteration 1 - Original Dino MSE for Image 240 = 0.023426877334713936
# Iteration 1 - Updated Dino MSE for Image 240 = 0.027647176757454872
# Iteration 1 - Difference = 0.004220299422740936
#
# Iteration 1 - Original Dino MSE for Image 241 = 0.028108544647693634
# Iteration 1 - Updated Dino MSE for Image 241 = 0.02655983343720436
# Iteration 1 - Difference = -0.001548711210489273
#
# Iteration 1 - Original Dino MSE for Image 242 = 0.01958998665213585
# Iteration 1 - Updated Dino MSE for Image 242 = 0.020460741594433784
# Iteration 1 - Difference = 0.0008707549422979355
#
# Iteration 1 - Original Dino MSE for Image 243 = 0.029491405934095383
# Iteration 1 - Updated Dino MSE for Image 243 = 0.027655409649014473
# Iteration 1 - Difference = -0.0018359962850809097
#
# Iteration 1 - Original Dino MSE for Image 244 = 0.04964442923665047
# Iteration 1 - Updated Dino MSE for Image 244 = 0.04571625962853432
# Iteration 1 - Difference = -0.00392816960811615
#
# Iteration 1 - Original Dino MSE for Image 245 = 0.03438912704586983
# Iteration 1 - Updated Dino MSE for Image 245 = 0.037015900015830994
# Iteration 1 - Difference = 0.0026267729699611664
#
# Iteration 1 - Original Dino MSE for Image 246 = 0.048052385449409485
# Iteration 1 - Updated Dino MSE for Image 246 = 0.04426320269703865
# Iteration 1 - Difference = -0.0037891827523708344
#
# Iteration 1 - Original Dino MSE for Image 247 = 0.04539152607321739
# Iteration 1 - Updated Dino MSE for Image 247 = 0.04637696221470833
# Iteration 1 - Difference = 0.0009854361414909363
#
# Iteration 1 - Original Dino MSE for Image 248 = 0.030026135966181755
# Iteration 1 - Updated Dino MSE for Image 248 = 0.033018484711647034
# Iteration 1 - Difference = 0.0029923487454652786
#
# Iteration 1 - Original Dino MSE for Image 249 = 0.043884214013814926
# Iteration 1 - Updated Dino MSE for Image 249 = 0.03979213535785675
# Iteration 1 - Difference = -0.004092078655958176
#
# Iteration 1 - Original Dino MSE for Image 250 = 0.06372496485710144
# Iteration 1 - Updated Dino MSE for Image 250 = 0.058868467807769775
# Iteration 1 - Difference = -0.004856497049331665
#
# Iteration 1 - Original Dino MSE for Image 251 = 0.0986725315451622
# Iteration 1 - Updated Dino MSE for Image 251 = 0.08991841971874237
# Iteration 1 - Difference = -0.00875411182641983
#
# Iteration 1 - Original Dino MSE for Image 252 = 0.07823262363672256
# Iteration 1 - Updated Dino MSE for Image 252 = 0.081082284450531
# Iteration 1 - Difference = 0.002849660813808441
#
# Iteration 1 - Original Dino MSE for Image 253 = 0.15012194216251373
# Iteration 1 - Updated Dino MSE for Image 253 = 0.13238680362701416
# Iteration 1 - Difference = -0.017735138535499573
#
# Iteration 1 - Original Dino MSE for Image 254 = 0.058310531079769135
# Iteration 1 - Updated Dino MSE for Image 254 = 0.06776174157857895
# Iteration 1 - Difference = 0.009451210498809814
#
# Iteration 1 - Original Dino MSE for Image 255 = 0.07352995127439499
# Iteration 1 - Updated Dino MSE for Image 255 = 0.07017379254102707
# Iteration 1 - Difference = -0.00335615873336792
#
# Iteration 1 - Original Dino MSE for Image 256 = 0.02617494761943817
# Iteration 1 - Updated Dino MSE for Image 256 = 0.03176839277148247
# Iteration 1 - Difference = 0.005593445152044296
#
# Iteration 1 - Original Dino MSE for Image 257 = 0.03403748571872711
# Iteration 1 - Updated Dino MSE for Image 257 = 0.03271039202809334
# Iteration 1 - Difference = -0.0013270936906337738
#
# Iteration 1 - Original Dino MSE for Image 258 = 0.04138430580496788
# Iteration 1 - Updated Dino MSE for Image 258 = 0.04082053154706955
# Iteration 1 - Difference = -0.0005637742578983307
#
# Iteration 1 - Original Dino MSE for Image 259 = 0.04779330641031265
# Iteration 1 - Updated Dino MSE for Image 259 = 0.04645739495754242
# Iteration 1 - Difference = -0.0013359114527702332
#
# Iteration 1 - Original Dino MSE for Image 260 = 0.0925666019320488
# Iteration 1 - Updated Dino MSE for Image 260 = 0.08139602839946747
# Iteration 1 - Difference = -0.01117057353258133
#
# Iteration 1 - Original Dino MSE for Image 261 = 0.03757007420063019
# Iteration 1 - Updated Dino MSE for Image 261 = 0.04177999123930931
# Iteration 1 - Difference = 0.004209917038679123
#
# Iteration 1 - Original Dino MSE for Image 262 = 0.026416044682264328
# Iteration 1 - Updated Dino MSE for Image 262 = 0.026745688170194626
# Iteration 1 - Difference = 0.00032964348793029785
#
# Iteration 1 - Original Dino MSE for Image 263 = 0.02799687162041664
# Iteration 1 - Updated Dino MSE for Image 263 = 0.027936985716223717
# Iteration 1 - Difference = -5.98859041929245e-05
#
# Iteration 1 - Original Dino MSE for Image 264 = 0.05837344005703926
# Iteration 1 - Updated Dino MSE for Image 264 = 0.052148181945085526
# Iteration 1 - Difference = -0.006225258111953735
#
# Iteration 1 - Original Dino MSE for Image 265 = 0.06169440224766731
# Iteration 1 - Updated Dino MSE for Image 265 = 0.058522194623947144
# Iteration 1 - Difference = -0.003172207623720169
#
# Iteration 1 - Original Dino MSE for Image 266 = 0.05811457708477974
# Iteration 1 - Updated Dino MSE for Image 266 = 0.06149257346987724
# Iteration 1 - Difference = 0.0033779963850975037
#
# Iteration 1 - Original Dino MSE for Image 267 = 0.07371163368225098
# Iteration 1 - Updated Dino MSE for Image 267 = 0.08534855395555496
# Iteration 1 - Difference = 0.011636920273303986
#
# Iteration 1 - Original Dino MSE for Image 268 = 0.06930267065763474
# Iteration 1 - Updated Dino MSE for Image 268 = 0.0706624835729599
# Iteration 1 - Difference = 0.0013598129153251648
#
# Iteration 1 - Original Dino MSE for Image 269 = 0.0768146738409996
# Iteration 1 - Updated Dino MSE for Image 269 = 0.07629381120204926
# Iteration 1 - Difference = -0.0005208626389503479
#
# Iteration 1 - Original Dino MSE for Image 270 = 0.09771155565977097
# Iteration 1 - Updated Dino MSE for Image 270 = 0.09653599560260773
# Iteration 1 - Difference = -0.0011755600571632385
#
# Iteration 1 - Original Dino MSE for Image 271 = 0.1062169075012207
# Iteration 1 - Updated Dino MSE for Image 271 = 0.10419483482837677
# Iteration 1 - Difference = -0.002022072672843933
#
# Iteration 1 - Original Dino MSE for Image 272 = 0.12050988525152206
# Iteration 1 - Updated Dino MSE for Image 272 = 0.12070678919553757
# Iteration 1 - Difference = 0.00019690394401550293
#
# Iteration 1 - Original Dino MSE for Image 273 = 0.09029463678598404
# Iteration 1 - Updated Dino MSE for Image 273 = 0.09144812822341919
# Iteration 1 - Difference = 0.0011534914374351501
#
# Iteration 1 - Original Dino MSE for Image 274 = 0.1030021607875824
# Iteration 1 - Updated Dino MSE for Image 274 = 0.10194682329893112
# Iteration 1 - Difference = -0.0010553374886512756
#
# Iteration 1 - Original Dino MSE for Image 275 = 0.08943481743335724
# Iteration 1 - Updated Dino MSE for Image 275 = 0.0851525068283081
# Iteration 1 - Difference = -0.004282310605049133
#
# Iteration 1 - Original Dino MSE for Image 276 = 0.09782162308692932
# Iteration 1 - Updated Dino MSE for Image 276 = 0.09032732248306274
# Iteration 1 - Difference = -0.007494300603866577
#
# Iteration 1 - Original Dino MSE for Image 277 = 0.11360804736614227
# Iteration 1 - Updated Dino MSE for Image 277 = 0.11189606040716171
# Iteration 1 - Difference = -0.0017119869589805603
#
# Iteration 1 - Original Dino MSE for Image 278 = 0.0949174016714096
# Iteration 1 - Updated Dino MSE for Image 278 = 0.09322930127382278
# Iteration 1 - Difference = -0.0016881003975868225
#
# Iteration 1 - Original Dino MSE for Image 279 = 0.11440544575452805
# Iteration 1 - Updated Dino MSE for Image 279 = 0.11215141415596008
# Iteration 1 - Difference = -0.0022540315985679626
#
# Iteration 1 - Original Dino MSE for Image 280 = 0.14300304651260376
# Iteration 1 - Updated Dino MSE for Image 280 = 0.161004438996315
# Iteration 1 - Difference = 0.018001392483711243
#
# Iteration 0 - Mean Original DINO MSE Across 281 Images = 0.1695290356874466
# Iteration 0 - Mean Updated DINO MSE Across 281 Images = 0.1626059114933014
# Iteration 0 - Mean Difference Across 281 Images = -0.006923107896000147, (-4.083729886108704 percent change relative to Vanilla DINOv2)
